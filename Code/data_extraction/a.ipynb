# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"total_post.csv")
df1.shape
# Out:
# C:\Users\pasqu\AppData\Local\Temp\ipykernel_6676\1873990149.py:1: DtypeWarning: Columns (4,10,11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(r"total_post.csv")
# (705953, 14)

# %%
df = df1.drop_duplicates().reset_index().drop("index",axis=1)
df
# Out:
#                                     id       post_pk  \
# 0        3558787428782179764_187264532  3.558787e+18
# 1        3557970465522674878_187264532  3.557970e+18
# 2        3557782854629238181_187264532  3.557783e+18
# 3        3557776470965660229_187264532  3.557776e+18
# 4        3556000079513982405_187264532  3.556000e+18
# ...                                ...           ...
# 658758  3442020028319915307_5760926442  3.442020e+18
# 658759  3441474864446536728_5760926442  3.441475e+18
# 658760  3439754127298093645_5760926442  3.439754e+18
# 658761  3439242148814721087_5760926442  3.439242e+18
# 658762  3439168885180909534_5760926442  3.439169e+18
#
#                                              caption_text  like_count  \
# 0                                       Behind the scenes         0.0
# 1                A little over 24 hours left to vote.\n\n         0.0
# 2       Galaxy Quest \nLots of cutting holes, playing ...         1.0
# ...

# %%
df.to_csv("total_post.csv",index=False)
