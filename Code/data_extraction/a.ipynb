# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"postAITS.csv")
df2 = pd.read_csv(r"postAITS2.csv")
df3 = pd.read_csv(r"postAITS3.csv")
df4 = pd.read_csv(r"postAITS4.csv")
df5 = pd.read_csv(r"postAITS5.csv")

# %%
df = pd.concat([df1,df2,df3,df4,df5]).drop_duplicates()
df
# Out:
#                                      id       post_pk  \
# 0         3558787428782179764_187264532  3.558787e+18
# 1         3557970465522674878_187264532  3.557970e+18
# 2         3557782854629238181_187264532  3.557783e+18
# 3         3557776470965660229_187264532  3.557776e+18
# 4         3556000079513982405_187264532  3.556000e+18
# ...                                 ...           ...
# 133302  3575014769692682879_62270892756  3.575015e+18
# 133303  3574960067294644779_62270892756  3.574960e+18
# 133304  3574959296431870237_62270892756  3.574959e+18
# 133305  3574957613710801225_62270892756  3.574958e+18
# 133306  3574956079400856243_62270892756  3.574956e+18
#
#                                              caption_text  like_count  \
# 0                                       Behind the scenes         0.0
# 1                A little over 24 hours left to vote.\n\n         0.0
# 2       Galaxy Quest \nLots of cutting holes, playing ...         1.0
# ...
