# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"total_postTS.csv").drop("Unnamed: 0",axis=1)
df1
# Out:
# C:\Users\pasqu\AppData\Local\Temp\ipykernel_13704\1554508265.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(r"total_postTS.csv").drop("Unnamed: 0",axis=1)
#                                      id       post_pk  \
# 0         3558787428782179764_187264532  3.558787e+18
# 1         3557970465522674878_187264532  3.557970e+18
# 2         3557782854629238181_187264532  3.557783e+18
# 3         3557776470965660229_187264532  3.557776e+18
# 4         3556000079513982405_187264532  3.556000e+18
# ...                                 ...           ...
# 531913    3574032018928974162_298552484  3.574032e+18
# 531914    3572867304598908171_298552484  3.572867e+18
# 531915    3563611016770577285_298552484  3.563611e+18
# 531916  3576046897956020504_70187202273  3.576047e+18
# 531917  3576046933884525218_70187202273  3.576047e+18
#
#                                              caption_text  like_count  \
# ...

# %%
n = len(df1)//3
n
# Out:
# 177306

# %%
df2 = df1[:n]
df3 = df1[n:2*n]
df4 = df1[2*n:]

# %%
df2.to_csv("total_post1.csv",index=False)
df3.to_csv("total_post2.csv",index=False)
df4.to_csv("total_post3.csv",index=False)
