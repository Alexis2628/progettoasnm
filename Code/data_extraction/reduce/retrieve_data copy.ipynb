# %%
import logging
import pandas as pd
import os
import json
import time

# %%
with open("session.txt", "r") as f:
    sessionid = f.read()

# %%
headers_for_html_fetching = {
            'Authority': 'www.threads.net',
            'Accept': (
                'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;'
                'q=0.8,application/signed-exchange;v=b3;q=0.7'
            ),
            'Accept-Language': 'en-US,en;q=0.9',
            'Cache-Control': 'no-cache',
            'Content-Type': 'application/x-www-form-urlencoded',
            'Origin': 'https://www.threads.net',
            'Pragma': 'no-cache',
            'Referer': 'https://www.instagram.com',
            'Sec-Fetch-Dest': 'document',
            'Sec-Fetch-Mode': 'navigate',
            'Sec-Fetch-Site': 'cross-site',
            'Sec-Fetch-User': '?1',
            'Upgrade-Insecure-Requests': '1',
            'User-Agent': (
                'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) '
                'AppleWebKit/605.1.15 (KHTML, like Gecko) Version/11.1.2 Safari/605.1.15'
            ),
        }

# %%
import requests

def getuserfollowers(userid, after):

	url = "https://threads-api4.p.rapidapi.com/api/user/followers"

	querystring = {"user_id":userid,"end_cursor":after}

	# headers = {
	# 	"x-rapidapi-key": "33597f1514msh76f2ee2bf3e48abp12819cjsn0b3bbf51a993",
	# 	"x-rapidapi-host": "threads-api4.p.rapidapi.com"
	# }

	headers = {
		'x-rapidapi-key': "110a6c40e2msh84b7d831ac51c42p16225bjsna1e5d1776e12",
		'x-rapidapi-host': "threads-api4.p.rapidapi.com"
	}
 
	response = requests.get(url, headers=headers, params=querystring)
	if response.json()["message"].__contains__("You have exceeded the MONTHLY quota for Requests on your current plan"):
		raise Exception()
	return response.json()

# getuserfollowers("1172237643", "0")

# %%
import re
def get_threads_userpk(username:str):
    cookies = {
            "sessionid": sessionid
    }
    response = requests.get(
                url=f'https://www.threads.net/@{username}',
                headers=headers_for_html_fetching,
                cookies=cookies
            )
    try:
        user_id_key_value = re.search('"user_id":"(\\d+)",', response.text).group()
        user_id = re.search('\\d+', user_id_key_value).group()
    except:
        raise Exception()
    return user_id

# get_threads_userpk("beiyo_")

# %%
dff = pd.read_csv("followers_Artificial_Intelligence.csv")
dff[dff["follower_pk"]==69655371289]#["follower_username"].unique()[0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, user_pk, follower_pk, follower_username, follower_count]
# Index: []

# %%
from retrieve_data_by_query import RetrieveDataByQuery
t = RetrieveDataByQuery(sessionid=sessionid)
t.retrieve_follower_by_userid_after("2018198806","0")
# Out:
# {'errors': [{'message': 'execution error',
#    'path': ['fetch__XDTUserDict'],
#    'severity': 'CRITICAL'}],
#  'data': None,
#  'extensions': {'is_final': True},
#  'status': 'ok'}

# %%
# query = "Artificial Intelligence"

# %%
def get_follower_data(data: list):
    try:
        return [
            {
                "pk": node.get("pk", ""),
                "username": node.get("username", ""),
                "follower_count": node.get("follower_count", "")
            }
            for d in data
            if (node := d.get("node", {}))
        ]
    except Exception as e:
        raise RuntimeError(f"Errore durante l'elaborazione dei dati dei follower: {e}")


progress_tracker = {}
filejson = "progress22.json"

def save_progress(userid: str, batch_number: int, results: list):
    """Salva il batch_number corrente e i risultati ottenuti per un determinato userid."""
    progress_tracker[userid] = {"batch_number": batch_number, "results": results}
    with open(filejson, "w") as f:
        json.dump(progress_tracker, f)

def load_progress(userid: str):
    """Carica il batch_number e i risultati salvati per un determinato userid."""
    try:
        with open(filejson, "r") as f:
            data = json.load(f)
            return data.get(userid, {"batch_number": 1, "results": []})
    except (FileNotFoundError, json.JSONDecodeError):
        return {"batch_number": 1, "results": []}
def remove_progress(userid: str):
    """Rimuove il progresso salvato per un determinato userid."""
    try:
        with open(filejson, "r") as f:
            data = json.load(f)
        
        if userid in data:
            del data[userid]
            with open(filejson, "w") as f:
                json.dump(data, f)
    except (FileNotFoundError, json.JSONDecodeError):
        pass
    
def get_all_follower(userid: str):
    progress = load_progress(userid)
    batch_number = progress["batch_number"]
    results = progress["results"]
    allpk = [res["pk"] for res in results]
    try:
        has_next_page = True
        while has_next_page:
            try:
                print("Pagina:", batch_number)
                # time.sleep(2)
                response = t.retrieve_follower_by_userid_after(userid, str(25 * batch_number-1))
                # response = getuserfollowe(userid, str(25 * batch_number-1))
                batch_number += 1
                data = response.get("data", {}).get("fetch__XDTUserDict", {}).get("followers", {})
                if data.get("edges", []) == []:
                    return [{
                        "pk": userid,
                        "username": None,
                        "follower_count": None
                    }]
                d_out = get_follower_data(data.get("edges", []))
                for res in d_out:
                    if res["pk"] in allpk:
                        remove_progress(userid)
                        return results
                    allpk.append(res["pk"])
                results.extend(d_out)
                
                has_next_page = data.get("page_info", {}).get("has_next_page", False)
                
                # Salva il progresso dopo ogni batch
                save_progress(userid, batch_number, results)
                
            except Exception as e:
                save_progress(userid, batch_number, results)  # Salva il batch e i risultati in caso di errore
                raise RuntimeError(f"Errore nel recupero della paginazione dei follower: {e}")
    
    except Exception as e:
        save_progress(userid, batch_number, results)  # Salva il batch e i risultati in caso di errore generale
        raise RuntimeError(f"Errore generale nel recupero dei follower per l'utente {userid}: {e}")
    remove_progress(userid)
    return results




def get_post_data(posts: list):
    results = []
    for post in posts:
        dati = post["node"]["thread"]["thread_items"]
        for p in dati:
            d = p['post']
            if int(d.get("like_count", 0)) < 100:
                continue
            userpk = d.get("user", {}).get("pk", "")
            caption = d.get("caption", {})
            caption_text = caption.get("text", "") if caption else ""
            if caption_text == "":
                continue
            results.append({
                "pk": d.get("pk", ""),
                "user_pk": userpk,
                "caption": caption_text,
                "like_count": int(d.get("like_count", 0)),
                "taken_at": d.get("taken_at", "")
            })
    return results

# %%
# results = []
# response = t.retrieve_thread_by_query(query)
# data = response.get("data", {}).get("searchResults", {})
# results.extend(get_post_data(data.get("edges", [])))
# has_next_page = data.get("page_info", {}).get("has_next_page", False)
# after = data.get("page_info", {}).get("end_cursor")
# i = 1000

# while has_next_page and i > 0:
#     response = t.retrieve_thread_by_query_after(query, after)
#     data = response.get("data", {}).get("searchResults", {})
#     results.extend(get_post_data(data.get("edges", [])))
#     has_next_page = data.get("page_info", {}).get("has_next_page", False)
#     after = data.get("page_info", {}).get("end_cursor")
#     i -= 1

# # Creazione del DataFrame
# df = pd.DataFrame(results)
# df.shape

# %%
# df.drop_duplicates(inplace=True)
# df['taken_at'] = pd.to_datetime(df['taken_at'], unit='s')
# df.to_csv("data.csv", index=False)

# %%
df = pd.read_csv("followers_Artificial_Intelligence2.csv")
df['follower_pk'] = df['follower_pk'].astype(str)
unique_user_pk = df['follower_pk'].unique()
len(unique_user_pk)
# Out:
# 3893

# %%
def load_processed_users(file_path):
    if os.path.exists(file_path):
        logging.info(f"Loading processed users from {file_path}")
        df = pd.read_csv(file_path)
        df['user_pk'] = df['user_pk'].astype(str)
        return set(df['user_pk'].tolist())
    return set()

def save_to_csv(df, file_path):
    try:
        if os.path.exists(file_path):
            df.to_csv(file_path, mode='a', header=False, index=False)
        else:
            df.to_csv(file_path, index=False)
        logging.info(f"Saved {len(df)} records to {file_path}")
    except Exception as e:
        logging.error(f"Error saving data to {file_path}: {e}")
        
csv_file = "followers_followers_Artificial_Intelligence2.csv"
processed_users = load_processed_users(csv_file)

# %%
len(processed_users)
# Out:
# 902

# %%
print(len(unique_user_pk))
unique_user_pk = unique_user_pk[unique_user_pk != "339473819"]
unique_user_pk = unique_user_pk[unique_user_pk != "1796326818"]
unique_user_pk = unique_user_pk[unique_user_pk != "62403108702"]
unique_user_pk = unique_user_pk[unique_user_pk != "65935700845"]
unique_user_pk = unique_user_pk[unique_user_pk != "4246313757"]
unique_user_pk = unique_user_pk[unique_user_pk != "1377397225"]
unique_user_pk = unique_user_pk[unique_user_pk != "3377123"]
unique_user_pk = unique_user_pk[unique_user_pk != "1538659247"]
unique_user_pk = unique_user_pk[unique_user_pk != "3195442587"]
unique_user_pk = unique_user_pk[unique_user_pk != "6849514097"]

unique_user_pk = unique_user_pk[unique_user_pk != "3195442587"]
unique_user_pk = unique_user_pk[unique_user_pk != "3195442587"]
unique_user_pk = unique_user_pk[unique_user_pk != "3195442587"]
unique_user_pk = unique_user_pk[unique_user_pk != "3195442587"]
unique_user_pk = unique_user_pk[unique_user_pk != "3195442587"]
unique_user_pk = unique_user_pk[unique_user_pk != "3195442587"]
unique_user_pk = unique_user_pk[unique_user_pk != "3195442587"]

print(len(unique_user_pk))
# Out:
# 3893
# 3885

# %%
def fetch_followers(pk,user_pk):
    print(f"Fetching followers for user_pk: {pk}")
    try:
        follower_data = get_all_follower(pk)
        return [
            {
                "user_pk": user_pk,
                "follower_pk": follower["pk"],
                "follower_username": follower["username"],
                "follower_count": follower["follower_count"],
                "user_threads_userpk": pk
            }
            for follower in follower_data
        ]
    except Exception as e:
        logging.error(f"Error fetching followers for {pk}: {e}")
        return None



follower_list = []
batch_size = 1


print("Starting follower data collection")
for user_pk in unique_user_pk:
    if user_pk in processed_users:
        print(f"Skipping already processed user_pk: {user_pk}")
        continue
    
    processed_users.update([user_pk])
    username= dff[dff["follower_pk"] == int(user_pk)]["follower_username"].unique()[0]
    print(user_pk,username )
    threads_user_pk = get_threads_userpk(str(username))
    results = fetch_followers(threads_user_pk,user_pk)
    if results is None:
        break
    follower_list.extend(results)
    
    if follower_list:
        print(f"Processing batch of {len(follower_list)} followers")
        follower_df = pd.DataFrame(follower_list)
        save_to_csv(follower_df, csv_file)
        follower_list = []

if follower_list:
    print(f"Saving remaining {len(follower_list)} followers")
    follower_df = pd.DataFrame(follower_list)   
    save_to_csv(follower_df, csv_file)

print("Follower data collection completed")
# Out:
# Starting follower data collection
# Skipping already processed user_pk: 197517651
# Skipping already processed user_pk: 980925948
# Skipping already processed user_pk: 234040073
# Skipping already processed user_pk: 54040075581
# Skipping already processed user_pk: 8153680531
# Skipping already processed user_pk: 2413511968
# Skipping already processed user_pk: 49022874449
# Skipping already processed user_pk: 32805841
# Skipping already processed user_pk: 1692266172
# Skipping already processed user_pk: 54970708817
# Skipping already processed user_pk: 1511140444
# Skipping already processed user_pk: 64846557340
# Skipping already processed user_pk: 45249519982
# Skipping already processed user_pk: 65014672661
# Skipping already processed user_pk: 31954394
# Skipping already processed user_pk: 52454957273
# Skipping already processed user_pk: 1682349283
# Skipping already processed user_pk: 56534788703
# Skipping already processed user_pk: 32208526304
# Skipping already processed user_pk: 38726329714
# Skipping already processed user_pk: 4154250706
# Skipping already processed user_pk: 3784208826
# Skipping already processed user_pk: 3077618573
# Skipping already processed user_pk: 1514429754
# Skipping already processed user_pk: 226708685
# Skipping already processed user_pk: 15470256937
# Skipping already processed user_pk: 1583120898
# Skipping already processed user_pk: 12079694888
# Skipping already processed user_pk: 66859563278
# Skipping already processed user_pk: 4709718235
# Skipping already processed user_pk: 1437960490
# Skipping already processed user_pk: 848835527
# Skipping already processed user_pk: 2041955936
# Skipping already processed user_pk: 4153538753
# Skipping already processed user_pk: 607962334
# Skipping already processed user_pk: 56380900469
# Skipping already processed user_pk: 6165598195
# Skipping already processed user_pk: 7178700256
# Skipping already processed user_pk: 48163349939
# Skipping already processed user_pk: 1750820675
# Skipping already processed user_pk: 6867852601
# Skipping already processed user_pk: 48068204101
# Skipping already processed user_pk: 9387172055
# Skipping already processed user_pk: 63328483182
# Skipping already processed user_pk: 48658229360
# Skipping already processed user_pk: 8141589708
# Skipping already processed user_pk: 35044585813
# Skipping already processed user_pk: 61132233502
# Skipping already processed user_pk: 8790137660
# Skipping already processed user_pk: 1495389274
# Skipping already processed user_pk: 534089187
# Skipping already processed user_pk: 5516719867
# Skipping already processed user_pk: 5741890502
# Skipping already processed user_pk: 298801773
# Skipping already processed user_pk: 5765963651
# Skipping already processed user_pk: 9367284921
# Skipping already processed user_pk: 56007896421
# Skipping already processed user_pk: 1609041751
# Skipping already processed user_pk: 11420586
# Skipping already processed user_pk: 1669719224
# Skipping already processed user_pk: 3684782587
# Skipping already processed user_pk: 1259639357
# Skipping already processed user_pk: 183989248
# Skipping already processed user_pk: 66093168050
# Skipping already processed user_pk: 32347093163
# Skipping already processed user_pk: 1830362681
# Skipping already processed user_pk: 993659614
# Skipping already processed user_pk: 256408144
# Skipping already processed user_pk: 2544378011
# Skipping already processed user_pk: 483523552
# Skipping already processed user_pk: 9220584832
# Skipping already processed user_pk: 964362411
# Skipping already processed user_pk: 1387475085
# Skipping already processed user_pk: 52680030301
# Skipping already processed user_pk: 642441061
# Skipping already processed user_pk: 5754794583
# Skipping already processed user_pk: 44534505552
# Skipping already processed user_pk: 45411798
# Skipping already processed user_pk: 53774205695
# Skipping already processed user_pk: 59809081856
# Skipping already processed user_pk: 1931553666
# Skipping already processed user_pk: 62331427235
# Skipping already processed user_pk: 1973291205
# Skipping already processed user_pk: 3237079124
# Skipping already processed user_pk: 17228863431
# Skipping already processed user_pk: 51459638
# Skipping already processed user_pk: 33184009035
# Skipping already processed user_pk: 186972089
# Skipping already processed user_pk: 35089547204
# Skipping already processed user_pk: 2034778841
# Skipping already processed user_pk: 1323231349
# Skipping already processed user_pk: 548360522
# Skipping already processed user_pk: 8242935602
# Skipping already processed user_pk: 222203464
# Skipping already processed user_pk: 647853924
# Skipping already processed user_pk: 259541936
# Skipping already processed user_pk: 8200960384
# Skipping already processed user_pk: 31442194
# Skipping already processed user_pk: 3663649770
# Skipping already processed user_pk: 2058952249
# Skipping already processed user_pk: 11299227124
# Skipping already processed user_pk: 5835558185
# Skipping already processed user_pk: 66502338621
# Skipping already processed user_pk: 4952238528
# Skipping already processed user_pk: 3271234710
# Skipping already processed user_pk: 454822084
# Skipping already processed user_pk: 2051665687
# Skipping already processed user_pk: 1454000768
# Skipping already processed user_pk: 186079335
# Skipping already processed user_pk: 56710183840
# Skipping already processed user_pk: 197352087
# Skipping already processed user_pk: 45288841112
# Skipping already processed user_pk: 48673268508
# Skipping already processed user_pk: 22972954687
# Skipping already processed user_pk: 2249147773
# Skipping already processed user_pk: 6174807515
# Skipping already processed user_pk: 2603506020
# Skipping already processed user_pk: 1415309191
# Skipping already processed user_pk: 28885237831
# Skipping already processed user_pk: 1808013515
# Skipping already processed user_pk: 5775047249
# Skipping already processed user_pk: 7138194725
# Skipping already processed user_pk: 5641313569
# Skipping already processed user_pk: 1748928908
# Skipping already processed user_pk: 1552157029
# Skipping already processed user_pk: 5347556224
# Skipping already processed user_pk: 3477393360
# Skipping already processed user_pk: 4605873090
# Skipping already processed user_pk: 9446726069
# Skipping already processed user_pk: 5811684117
# Skipping already processed user_pk: 8670439911
# Skipping already processed user_pk: 1623651836
# Skipping already processed user_pk: 55294903443
# Skipping already processed user_pk: 1231899491
# Skipping already processed user_pk: 60429149073
# Skipping already processed user_pk: 981959277
# Skipping already processed user_pk: 4253602733
# Skipping already processed user_pk: 50537928502
# Skipping already processed user_pk: 8231695445
# Skipping already processed user_pk: 309086262
# Skipping already processed user_pk: 2089453742
# Skipping already processed user_pk: 335687584
# Skipping already processed user_pk: 3237778266
# Skipping already processed user_pk: 519830557
# Skipping already processed user_pk: 3402763899
# Skipping already processed user_pk: 1903214221
# Skipping already processed user_pk: 3301119676
# Skipping already processed user_pk: 436764910
# Skipping already processed user_pk: 280971223
# Skipping already processed user_pk: 61349305118
# Skipping already processed user_pk: 53788344369
# Skipping already processed user_pk: 1181629644
# Skipping already processed user_pk: 1577461835
# Skipping already processed user_pk: 517940705
# Skipping already processed user_pk: 42274313933
# Skipping already processed user_pk: 4521910787
# Skipping already processed user_pk: 233527306
# Skipping already processed user_pk: 2275994903
# Skipping already processed user_pk: 4781643365
# Skipping already processed user_pk: 528829702
# Skipping already processed user_pk: 4717204336
# Skipping already processed user_pk: 187277857
# Skipping already processed user_pk: 1725035341
# Skipping already processed user_pk: 639659972
# Skipping already processed user_pk: 66616224409
# Skipping already processed user_pk: 471297358
# Skipping already processed user_pk: 367971895
# Skipping already processed user_pk: 1403575483
# Skipping already processed user_pk: 31320369
# Skipping already processed user_pk: 57253783373
# Skipping already processed user_pk: 760592960
# Skipping already processed user_pk: 4235206036
# Skipping already processed user_pk: 4011470576
# Skipping already processed user_pk: 16801882547
# Skipping already processed user_pk: 877657137
# Skipping already processed user_pk: 51910353810
# Skipping already processed user_pk: 257236794
# Skipping already processed user_pk: 1367304985
# Skipping already processed user_pk: 45080752
# Skipping already processed user_pk: 67788947429
# Skipping already processed user_pk: 1575970894
# Skipping already processed user_pk: 1577122323
# Skipping already processed user_pk: 8281926103
# Skipping already processed user_pk: 8753732105
# Skipping already processed user_pk: 2119740364
# Skipping already processed user_pk: 65212103331
# Skipping already processed user_pk: 61520010888
# Skipping already processed user_pk: 5650838171
# Skipping already processed user_pk: 259362550
# Skipping already processed user_pk: 3043137945
# Skipping already processed user_pk: 43984998372
# Skipping already processed user_pk: 48884662190
# Skipping already processed user_pk: 352817767
# Skipping already processed user_pk: 178479814
# Skipping already processed user_pk: 49299526437
# Skipping already processed user_pk: 48377782222
# Skipping already processed user_pk: 598151628
# Skipping already processed user_pk: 14512708643
# Skipping already processed user_pk: 2462441871
# Skipping already processed user_pk: 3204255848
# Skipping already processed user_pk: 361918141
# Skipping already processed user_pk: 65310203283
# Skipping already processed user_pk: 63447057871
# Skipping already processed user_pk: 53582012236
# Skipping already processed user_pk: 638291895
# Skipping already processed user_pk: 1254309363
# Skipping already processed user_pk: 46046651281
# Skipping already processed user_pk: 38417501563
# Skipping already processed user_pk: 5375219332
# Skipping already processed user_pk: 358073985
# Skipping already processed user_pk: 282387412
# Skipping already processed user_pk: 1750927568
# Skipping already processed user_pk: 55775149841
# Skipping already processed user_pk: 5733031996
# Skipping already processed user_pk: 49228140183
# Skipping already processed user_pk: 330685330
# Skipping already processed user_pk: 2127111959
# Skipping already processed user_pk: 1008554761
# Skipping already processed user_pk: 1376242331
# Skipping already processed user_pk: 4446173210
# Skipping already processed user_pk: 210154937
# Skipping already processed user_pk: 3072150878
# Skipping already processed user_pk: 48333165161
# Skipping already processed user_pk: 3080721163
# Skipping already processed user_pk: 6025498107
# Skipping already processed user_pk: 1371137868
# Skipping already processed user_pk: 1666589051
# Skipping already processed user_pk: 532882872
# Skipping already processed user_pk: 3173899039
# Skipping already processed user_pk: 3253555047
# Skipping already processed user_pk: 68294375328
# Skipping already processed user_pk: 47398193366
# Skipping already processed user_pk: 1561432980
# Skipping already processed user_pk: 1058544342
# Skipping already processed user_pk: 62264623228
# Skipping already processed user_pk: 44977401080
# Skipping already processed user_pk: 8354933769
# Skipping already processed user_pk: 61993226274
# Skipping already processed user_pk: 977318067
# Skipping already processed user_pk: 42871877624
# Skipping already processed user_pk: 2518387115
# Skipping already processed user_pk: 1005522208
# Skipping already processed user_pk: 4776302895
# Skipping already processed user_pk: 18205274
# Skipping already processed user_pk: 5370305722
# Skipping already processed user_pk: 395092326
# Skipping already processed user_pk: 34418317835
# Skipping already processed user_pk: 5654524827
# Skipping already processed user_pk: 4153621015
# Skipping already processed user_pk: 7393172234
# Skipping already processed user_pk: 4957087785
# Skipping already processed user_pk: 48730334580
# Skipping already processed user_pk: 57267567965
# Skipping already processed user_pk: 145750785
# Skipping already processed user_pk: 48321651
# Skipping already processed user_pk: 1324404899
# Skipping already processed user_pk: 391592514
# Skipping already processed user_pk: 849340756
# Skipping already processed user_pk: 6948558772
# Skipping already processed user_pk: 2234355676
# Skipping already processed user_pk: 45601217635
# Skipping already processed user_pk: 1405947276
# Skipping already processed user_pk: 2037567381
# Skipping already processed user_pk: 2083457320
# Skipping already processed user_pk: 52285518139
# Skipping already processed user_pk: 2435387027
# Skipping already processed user_pk: 2312972872
# Skipping already processed user_pk: 20266139
# Skipping already processed user_pk: 1968141225
# Skipping already processed user_pk: 7577658915
# Skipping already processed user_pk: 426470394
# Skipping already processed user_pk: 1557167614
# Skipping already processed user_pk: 51579558415
# Skipping already processed user_pk: 38090866141
# Skipping already processed user_pk: 58359057174
# Skipping already processed user_pk: 232463019
# Skipping already processed user_pk: 25367935423
# Skipping already processed user_pk: 8926854171
# Skipping already processed user_pk: 871895200
# Skipping already processed user_pk: 1224138065
# Skipping already processed user_pk: 3209816317
# Skipping already processed user_pk: 1787284400
# Skipping already processed user_pk: 1599991832
# Skipping already processed user_pk: 17860746
# Skipping already processed user_pk: 3649041343
# Skipping already processed user_pk: 2062352492
# Skipping already processed user_pk: 9147466800
# Skipping already processed user_pk: 1485055212
# Skipping already processed user_pk: 1607423401
# Skipping already processed user_pk: 14574642010
# Skipping already processed user_pk: 1833221446
# Skipping already processed user_pk: 3489626448
# Skipping already processed user_pk: 3496293601
# Skipping already processed user_pk: 49241601740
# Skipping already processed user_pk: 1992572150
# Skipping already processed user_pk: 1427727116
# Skipping already processed user_pk: 901434477
# Skipping already processed user_pk: 270253358
# Skipping already processed user_pk: 208082472
# Skipping already processed user_pk: 56982360616
# Skipping already processed user_pk: 4537877333
# Skipping already processed user_pk: 28143083614
# Skipping already processed user_pk: 2921343779
# Skipping already processed user_pk: 51691710112
# Skipping already processed user_pk: 1833554864
# Skipping already processed user_pk: 6200754767
# Skipping already processed user_pk: 16660088887
# Skipping already processed user_pk: 58749976768
# Skipping already processed user_pk: 5518783368
# Skipping already processed user_pk: 5736427431
# Skipping already processed user_pk: 6283397034
# Skipping already processed user_pk: 67338215422
# Skipping already processed user_pk: 30105728734
# Skipping already processed user_pk: 66280301575
# Skipping already processed user_pk: 5404583349
# Skipping already processed user_pk: 60832644801
# Skipping already processed user_pk: 8535235430
# Skipping already processed user_pk: 62122602222
# Skipping already processed user_pk: 365226711
# Skipping already processed user_pk: 1386020418
# Skipping already processed user_pk: 220277996
# Skipping already processed user_pk: 272778674
# Skipping already processed user_pk: 5929062865
# Skipping already processed user_pk: 8532245804
# Skipping already processed user_pk: 5929058413
# Skipping already processed user_pk: 47678258668
# Skipping already processed user_pk: 1769360013
# Skipping already processed user_pk: 3543771214
# Skipping already processed user_pk: 251109033
# Skipping already processed user_pk: 794831539
# Skipping already processed user_pk: 6647178641
# Skipping already processed user_pk: 1491998240
# Skipping already processed user_pk: 1681510644
# Skipping already processed user_pk: 907881505
# Skipping already processed user_pk: 7039738722
# Skipping already processed user_pk: 2166849175
# Skipping already processed user_pk: 46898365393
# Skipping already processed user_pk: 1532763890
# Skipping already processed user_pk: 62328640948
# Skipping already processed user_pk: 2078317371
# Skipping already processed user_pk: 4971960412
# Skipping already processed user_pk: 64757819170
# Skipping already processed user_pk: 5542328186
# Skipping already processed user_pk: 5326175166
# Skipping already processed user_pk: 68169304610
# Skipping already processed user_pk: 264608475
# Skipping already processed user_pk: 1364633117
# Skipping already processed user_pk: 33663953
# Skipping already processed user_pk: 59849177000
# Skipping already processed user_pk: 1952443018
# Skipping already processed user_pk: 65148573826
# Skipping already processed user_pk: 255478303
# Skipping already processed user_pk: 422320840
# Skipping already processed user_pk: 4741645272
# Skipping already processed user_pk: 1372122212
# Skipping already processed user_pk: 6610651776
# Skipping already processed user_pk: 16671031756
# Skipping already processed user_pk: 225889557
# Skipping already processed user_pk: 192027513
# Skipping already processed user_pk: 26142475
# Skipping already processed user_pk: 3572990454
# Skipping already processed user_pk: 50021931435
# Skipping already processed user_pk: 46639439573
# Skipping already processed user_pk: 1911867974
# Skipping already processed user_pk: 44719045842
# Skipping already processed user_pk: 5424838826
# Skipping already processed user_pk: 650820315
# Skipping already processed user_pk: 62464202068
# Skipping already processed user_pk: 51672236
# Skipping already processed user_pk: 2177068291
# Skipping already processed user_pk: 256587098
# Skipping already processed user_pk: 66449175931
# Skipping already processed user_pk: 1814587532
# Skipping already processed user_pk: 2365546942
# Skipping already processed user_pk: 320900466
# Skipping already processed user_pk: 1038588005
# Skipping already processed user_pk: 1456092275
# Skipping already processed user_pk: 3668411883
# Skipping already processed user_pk: 7315466486
# Skipping already processed user_pk: 270680322
# Skipping already processed user_pk: 1914501508
# Skipping already processed user_pk: 5579774904
# Skipping already processed user_pk: 244490110
# Skipping already processed user_pk: 7995421100
# Skipping already processed user_pk: 7038257596
# Skipping already processed user_pk: 56290323780
# Skipping already processed user_pk: 1171538759
# Skipping already processed user_pk: 3276451003
# Skipping already processed user_pk: 7272948433
# Skipping already processed user_pk: 1284397127
# Skipping already processed user_pk: 66907829726
# Skipping already processed user_pk: 1225130685
# Skipping already processed user_pk: 4744174644
# Skipping already processed user_pk: 1836079921
# Skipping already processed user_pk: 18000401666
# Skipping already processed user_pk: 5960859429
# Skipping already processed user_pk: 294925374
# Skipping already processed user_pk: 47967649278
# Skipping already processed user_pk: 268418104
# Skipping already processed user_pk: 688855
# Skipping already processed user_pk: 52020023741
# Skipping already processed user_pk: 46356294597
# Skipping already processed user_pk: 1402114649
# Skipping already processed user_pk: 54263093
# Skipping already processed user_pk: 306667601
# Skipping already processed user_pk: 3924316666
# Skipping already processed user_pk: 2958579711
# Skipping already processed user_pk: 4563307926
# Skipping already processed user_pk: 12413637257
# Skipping already processed user_pk: 1097448990
# Skipping already processed user_pk: 1678858045
# Skipping already processed user_pk: 2081668366
# Skipping already processed user_pk: 47546791290
# Skipping already processed user_pk: 1576060977
# Skipping already processed user_pk: 2118635006
# Skipping already processed user_pk: 37280452906
# Skipping already processed user_pk: 4456698605
# Skipping already processed user_pk: 596135864
# Skipping already processed user_pk: 65935493017
# Skipping already processed user_pk: 1417662750
# Skipping already processed user_pk: 56198521110
# Skipping already processed user_pk: 5892349775
# Skipping already processed user_pk: 63874819562
# Skipping already processed user_pk: 1174944623
# Skipping already processed user_pk: 3141692406
# Skipping already processed user_pk: 5823545804
# Skipping already processed user_pk: 4122229410
# Skipping already processed user_pk: 6809942292
# Skipping already processed user_pk: 1785492908
# Skipping already processed user_pk: 3462899962
# Skipping already processed user_pk: 1693995370
# Skipping already processed user_pk: 3627281968
# Skipping already processed user_pk: 8195023673
# Skipping already processed user_pk: 5805829
# Skipping already processed user_pk: 65820395223
# Skipping already processed user_pk: 4235648417
# Skipping already processed user_pk: 65365548517
# Skipping already processed user_pk: 48920283162
# Skipping already processed user_pk: 284156688
# Skipping already processed user_pk: 6766399536
# Skipping already processed user_pk: 1614737368
# Skipping already processed user_pk: 56824175115
# Skipping already processed user_pk: 51762697825
# Skipping already processed user_pk: 63581399388
# Skipping already processed user_pk: 2125739
# Skipping already processed user_pk: 3950904238
# Skipping already processed user_pk: 388912547
# Skipping already processed user_pk: 7468828360
# Skipping already processed user_pk: 5463298413
# Skipping already processed user_pk: 2044117745
# Skipping already processed user_pk: 2260166226
# Skipping already processed user_pk: 17416740659
# Skipping already processed user_pk: 1526393177
# Skipping already processed user_pk: 56174359599
# Skipping already processed user_pk: 6861913115
# Skipping already processed user_pk: 49053280109
# Skipping already processed user_pk: 3028805127
# Skipping already processed user_pk: 4064777
# Skipping already processed user_pk: 11587162161
# Skipping already processed user_pk: 9370572341
# Skipping already processed user_pk: 47723464228
# Skipping already processed user_pk: 186938304
# Skipping already processed user_pk: 1562520056
# Skipping already processed user_pk: 3406671606
# Skipping already processed user_pk: 1420044578
# Skipping already processed user_pk: 3140999007
# Skipping already processed user_pk: 59527847968
# Skipping already processed user_pk: 346193323
# Skipping already processed user_pk: 2227671287
# Skipping already processed user_pk: 52921962117
# Skipping already processed user_pk: 3166261582
# Skipping already processed user_pk: 58675678510
# Skipping already processed user_pk: 4550565142
# Skipping already processed user_pk: 7878083453
# Skipping already processed user_pk: 1812708262
# Skipping already processed user_pk: 8120167302
# Skipping already processed user_pk: 1360482547
# Skipping already processed user_pk: 1058905193
# Skipping already processed user_pk: 62224782899
# Skipping already processed user_pk: 61445485133
# Skipping already processed user_pk: 51512910586
# Skipping already processed user_pk: 67211832625
# Skipping already processed user_pk: 2317764069
# Skipping already processed user_pk: 1651408700
# Skipping already processed user_pk: 1979300544
# Skipping already processed user_pk: 3430095240
# Skipping already processed user_pk: 8258564985
# Skipping already processed user_pk: 52745181698
# Skipping already processed user_pk: 66343763170
# Skipping already processed user_pk: 1904510877
# Skipping already processed user_pk: 53817470
# Skipping already processed user_pk: 61509484194
# Skipping already processed user_pk: 44343693850
# Skipping already processed user_pk: 1328768312
# Skipping already processed user_pk: 3307386429
# Skipping already processed user_pk: 3634099737
# Skipping already processed user_pk: 6268588202
# Skipping already processed user_pk: 1705997868
# Skipping already processed user_pk: 34652672
# Skipping already processed user_pk: 1546064829
# Skipping already processed user_pk: 1307863979
# Skipping already processed user_pk: 643870080
# Skipping already processed user_pk: 7765815968
# Skipping already processed user_pk: 5677875352
# Skipping already processed user_pk: 51192877495
# Skipping already processed user_pk: 55974506876
# Skipping already processed user_pk: 1791783780
# Skipping already processed user_pk: 6767253674
# Skipping already processed user_pk: 3507995717
# Skipping already processed user_pk: 3566397996
# Skipping already processed user_pk: 2266326897
# Skipping already processed user_pk: 2050298607
# Skipping already processed user_pk: 8489932401
# Skipping already processed user_pk: 8026955862
# Skipping already processed user_pk: 1054944367
# Skipping already processed user_pk: 51808878577
# Skipping already processed user_pk: 4212252282
# Skipping already processed user_pk: 46009451423
# Skipping already processed user_pk: 5050500430
# Skipping already processed user_pk: 25589189653
# Skipping already processed user_pk: 7312103071
# Skipping already processed user_pk: 50957527632
# Skipping already processed user_pk: 38987615528
# Skipping already processed user_pk: 4086368562
# Skipping already processed user_pk: 6344165928
# Skipping already processed user_pk: 46958831610
# Skipping already processed user_pk: 5454676551
# Skipping already processed user_pk: 254835508
# Skipping already processed user_pk: 2039714098
# Skipping already processed user_pk: 5629619615
# Skipping already processed user_pk: 64209704673
# Skipping already processed user_pk: 8696834451
# Skipping already processed user_pk: 2289828448
# Skipping already processed user_pk: 2917351187
# Skipping already processed user_pk: 1582770711
# Skipping already processed user_pk: 4686296362
# Skipping already processed user_pk: 12738896688
# Skipping already processed user_pk: 4238430266
# Skipping already processed user_pk: 5412581699
# Skipping already processed user_pk: 54845699940
# Skipping already processed user_pk: 5382176116
# Skipping already processed user_pk: 28726466938
# Skipping already processed user_pk: 6156577303
# Skipping already processed user_pk: 268445245
# Skipping already processed user_pk: 998415024
# Skipping already processed user_pk: 61106624659
# Skipping already processed user_pk: 5717095476
# Skipping already processed user_pk: 31682657939
# Skipping already processed user_pk: 51842625849
# Skipping already processed user_pk: 61624696712
# Skipping already processed user_pk: 34437509725
# Skipping already processed user_pk: 1042119263
# Skipping already processed user_pk: 21992611944
# Skipping already processed user_pk: 4102830529
# Skipping already processed user_pk: 6165821044
# Skipping already processed user_pk: 66282885639
# Skipping already processed user_pk: 4757720809
# Skipping already processed user_pk: 8049790393
# Skipping already processed user_pk: 59491162529
# Skipping already processed user_pk: 47783354942
# Skipping already processed user_pk: 5672499286
# Skipping already processed user_pk: 5601055403
# Skipping already processed user_pk: 60603054516
# Skipping already processed user_pk: 56288883447
# Skipping already processed user_pk: 61803500354
# Skipping already processed user_pk: 1058691218
# Skipping already processed user_pk: 45575388733
# Skipping already processed user_pk: 6338257204
# Skipping already processed user_pk: 56099732635
# Skipping already processed user_pk: 5385742608
# Skipping already processed user_pk: 3890160
# Skipping already processed user_pk: 2304435089
# Skipping already processed user_pk: 15119780
# Skipping already processed user_pk: 264448209
# Skipping already processed user_pk: 3410486595
# Skipping already processed user_pk: 2885563705
# Skipping already processed user_pk: 3057082905
# Skipping already processed user_pk: 1473759090
# Skipping already processed user_pk: 3505937603
# Skipping already processed user_pk: 49758895166
# Skipping already processed user_pk: 49339821514
# Skipping already processed user_pk: 65707315192
# Skipping already processed user_pk: 43133226114
# Skipping already processed user_pk: 58191581564
# Skipping already processed user_pk: 5405856158
# Skipping already processed user_pk: 64057552054
# Skipping already processed user_pk: 3079287
# Skipping already processed user_pk: 7484056270
# Skipping already processed user_pk: 594063179
# Skipping already processed user_pk: 63393091428
# Skipping already processed user_pk: 8802194029
# Skipping already processed user_pk: 1624600187
# Skipping already processed user_pk: 199019059
# Skipping already processed user_pk: 2994328058
# Skipping already processed user_pk: 33039583
# Skipping already processed user_pk: 1694340307
# Skipping already processed user_pk: 1358878526
# Skipping already processed user_pk: 58692158610
# Skipping already processed user_pk: 53520145530
# Skipping already processed user_pk: 1109185572
# Skipping already processed user_pk: 31062256
# Skipping already processed user_pk: 2802763064
# Skipping already processed user_pk: 269191792
# Skipping already processed user_pk: 232949845
# Skipping already processed user_pk: 273781333
# Skipping already processed user_pk: 7367701547
# Skipping already processed user_pk: 6696890867
# Skipping already processed user_pk: 2197924964
# Skipping already processed user_pk: 1596691527
# Skipping already processed user_pk: 1994999776
# Skipping already processed user_pk: 311579937
# Skipping already processed user_pk: 60195557653
# Skipping already processed user_pk: 4298590693
# Skipping already processed user_pk: 341164
# Skipping already processed user_pk: 225829610
# Skipping already processed user_pk: 9053644139
# Skipping already processed user_pk: 201868598
# Skipping already processed user_pk: 2028960081
# Skipping already processed user_pk: 1149139976
# Skipping already processed user_pk: 6750617884
# Skipping already processed user_pk: 383759288
# Skipping already processed user_pk: 9929285
# Skipping already processed user_pk: 526102413
# Skipping already processed user_pk: 336124890
# Skipping already processed user_pk: 1703261008
# Skipping already processed user_pk: 53914555573
# Skipping already processed user_pk: 18651259392
# Skipping already processed user_pk: 410527886
# Skipping already processed user_pk: 626957007
# Skipping already processed user_pk: 4228232317
# Skipping already processed user_pk: 3897706009
# Skipping already processed user_pk: 2001001851
# Skipping already processed user_pk: 8250832887
# Skipping already processed user_pk: 5611211274
# Skipping already processed user_pk: 718763683
# Skipping already processed user_pk: 1561130014
# Skipping already processed user_pk: 3050305137
# Skipping already processed user_pk: 17085461820
# Skipping already processed user_pk: 8986766659
# Skipping already processed user_pk: 8988804166
# Skipping already processed user_pk: 1744252130
# Skipping already processed user_pk: 144073542
# Skipping already processed user_pk: 57812674888
# Skipping already processed user_pk: 1163559305
# Skipping already processed user_pk: 4053814573
# Skipping already processed user_pk: 7038865341
# Skipping already processed user_pk: 988734461
# Skipping already processed user_pk: 6917251483
# Skipping already processed user_pk: 3231199205
# Skipping already processed user_pk: 1519726959
# Skipping already processed user_pk: 10156922088
# Skipping already processed user_pk: 970266778
# Skipping already processed user_pk: 5611809839
# Skipping already processed user_pk: 234527271
# Skipping already processed user_pk: 523393929
# Skipping already processed user_pk: 48833272373
# Skipping already processed user_pk: 5952032837
# Skipping already processed user_pk: 7250668554
# Skipping already processed user_pk: 1953696
# Skipping already processed user_pk: 310893075
# Skipping already processed user_pk: 4193259260
# Skipping already processed user_pk: 190991600
# Skipping already processed user_pk: 799565844
# Skipping already processed user_pk: 380382950
# Skipping already processed user_pk: 1390513280
# Skipping already processed user_pk: 322048988
# Skipping already processed user_pk: 7797061882
# Skipping already processed user_pk: 2754551962
# Skipping already processed user_pk: 8147342359
# Skipping already processed user_pk: 46052227
# Skipping already processed user_pk: 755757
# Skipping already processed user_pk: 503180970
# Skipping already processed user_pk: 478929975
# Skipping already processed user_pk: 64120493081
# Skipping already processed user_pk: 230152778
# Skipping already processed user_pk: 954301257
# Skipping already processed user_pk: 1951008507
# Skipping already processed user_pk: 235449558
# Skipping already processed user_pk: 207979140
# Skipping already processed user_pk: 5159602140
# Skipping already processed user_pk: 16743536063
# Skipping already processed user_pk: 1502605113
# Skipping already processed user_pk: 295495977
# Skipping already processed user_pk: 1774141847
# Skipping already processed user_pk: 2308677404
# Skipping already processed user_pk: 2066306061
# Skipping already processed user_pk: 633050884
# Skipping already processed user_pk: 5909444308
# Skipping already processed user_pk: 200044455
# Skipping already processed user_pk: 412940200
# Skipping already processed user_pk: 45565307491
# Skipping already processed user_pk: 67299816650
# Skipping already processed user_pk: 1511287722
# Skipping already processed user_pk: 469690619
# Skipping already processed user_pk: 239223026
# Skipping already processed user_pk: 4297776173
# Skipping already processed user_pk: 44883245
# Skipping already processed user_pk: 10844983061
# Skipping already processed user_pk: 274461717
# Skipping already processed user_pk: 2142063426
# Skipping already processed user_pk: 1407904151
# Skipping already processed user_pk: 71613213096
# Skipping already processed user_pk: 68751449548
# Skipping already processed user_pk: 17082866383
# Skipping already processed user_pk: 46197410447
# Skipping already processed user_pk: 56308644834
# Skipping already processed user_pk: 67472339240
# Skipping already processed user_pk: 71863258348
# Skipping already processed user_pk: 45326394165
# Skipping already processed user_pk: 59429203236
# Skipping already processed user_pk: 64398197315
# Skipping already processed user_pk: 64727281663
# Skipping already processed user_pk: 58176327965
# Skipping already processed user_pk: 9141131782
# Skipping already processed user_pk: 6043765350
# Skipping already processed user_pk: 71422901119
# Skipping already processed user_pk: 57624282225
# Skipping already processed user_pk: 53361895997
# Skipping already processed user_pk: 47312992458
# Skipping already processed user_pk: 63790485861
# Skipping already processed user_pk: 67978722813
# Skipping already processed user_pk: 72493755585
# Skipping already processed user_pk: 58575140276
# Skipping already processed user_pk: 48743242149
# Skipping already processed user_pk: 9241589051
# Skipping already processed user_pk: 47588444302
# Skipping already processed user_pk: 468639049
# Skipping already processed user_pk: 247085757
# Skipping already processed user_pk: 27171301940
# Skipping already processed user_pk: 3411844417
# Skipping already processed user_pk: 7744153686
# Skipping already processed user_pk: 791768601
# Skipping already processed user_pk: 33239505840
# Skipping already processed user_pk: 58637232815
# Skipping already processed user_pk: 4063171621
# Skipping already processed user_pk: 54192956539
# Skipping already processed user_pk: 44569743778
# Skipping already processed user_pk: 3533888288
# Skipping already processed user_pk: 4567656513
# Skipping already processed user_pk: 71402518136
# Skipping already processed user_pk: 4290881747
# Skipping already processed user_pk: 1909794413
# Skipping already processed user_pk: 3117172772
# Skipping already processed user_pk: 2136051710
# Skipping already processed user_pk: 65765140894
# Skipping already processed user_pk: 33744180356
# Skipping already processed user_pk: 69043466398
# Skipping already processed user_pk: 71441679217
# Skipping already processed user_pk: 70969893217
# Skipping already processed user_pk: 5542269036
# Skipping already processed user_pk: 54966363361
# Skipping already processed user_pk: 61070486283
# Skipping already processed user_pk: 1217726197
# Skipping already processed user_pk: 6765889752
# Skipping already processed user_pk: 45281958185
# Skipping already processed user_pk: 55602359389
# Skipping already processed user_pk: 6848716046
# Skipping already processed user_pk: 57718975617
# Skipping already processed user_pk: 104967693
# Skipping already processed user_pk: 32125188
# Skipping already processed user_pk: 254323122
# Skipping already processed user_pk: 56350363439
# Skipping already processed user_pk: 5615843900
# Skipping already processed user_pk: 64155148570
# Skipping already processed user_pk: 225264454
# Skipping already processed user_pk: 60602802712
# Skipping already processed user_pk: 2338944180
# Skipping already processed user_pk: 38060880471
# Skipping already processed user_pk: 71124370294
# Skipping already processed user_pk: 1091690
# Skipping already processed user_pk: 29413269
# Skipping already processed user_pk: 3644402995
# Skipping already processed user_pk: 6861254154
# Skipping already processed user_pk: 10966419605
# Skipping already processed user_pk: 47930185222
# Skipping already processed user_pk: 929651219
# Skipping already processed user_pk: 63918526961
# Skipping already processed user_pk: 371729167
# Skipping already processed user_pk: 45456496040
# Skipping already processed user_pk: 38145506
# Skipping already processed user_pk: 70269678639
# Skipping already processed user_pk: 17740625
# Skipping already processed user_pk: 57265886603
# Skipping already processed user_pk: 14329033
# Skipping already processed user_pk: 68657746912
# Skipping already processed user_pk: 51205615808
# Skipping already processed user_pk: 1320434710
# Skipping already processed user_pk: 183533623
# Skipping already processed user_pk: 15672067162
# Skipping already processed user_pk: 55223511814
# Skipping already processed user_pk: 57853877524
# Skipping already processed user_pk: 13547903
# Skipping already processed user_pk: 54859540729
# Skipping already processed user_pk: 12146028725
# Skipping already processed user_pk: 229135196
# Skipping already processed user_pk: 53431764637
# Skipping already processed user_pk: 1524988041
# Skipping already processed user_pk: 38046183496
# Skipping already processed user_pk: 44265806815
# Skipping already processed user_pk: 44236088
# Skipping already processed user_pk: 2098495018
# Skipping already processed user_pk: 5958580954
# Skipping already processed user_pk: 1444174457
# Skipping already processed user_pk: 61379568345
# Skipping already processed user_pk: 67361606873
# Skipping already processed user_pk: 56783592678
# Skipping already processed user_pk: 6191134044
# Skipping already processed user_pk: 1494729869
# Skipping already processed user_pk: 2611752178
# Skipping already processed user_pk: 2274471865
# Skipping already processed user_pk: 18078856515
# Skipping already processed user_pk: 65525148025
# Skipping already processed user_pk: 8675235156
# Skipping already processed user_pk: 4145972211
# Skipping already processed user_pk: 2078058664
# Skipping already processed user_pk: 1409330029
# Skipping already processed user_pk: 56195677586
# Skipping already processed user_pk: 7229582557
# Skipping already processed user_pk: 599796445
# Skipping already processed user_pk: 15988463583
# Skipping already processed user_pk: 2100605388
# Skipping already processed user_pk: 65834808646
# Skipping already processed user_pk: 16886147667
# Skipping already processed user_pk: 3991072818
# Skipping already processed user_pk: 69771003486
# Skipping already processed user_pk: 44401963592
# Skipping already processed user_pk: 14659627102
# Skipping already processed user_pk: 351084736
# Skipping already processed user_pk: 51976556835
# Skipping already processed user_pk: 4218832191
# Skipping already processed user_pk: 72092570887
# Skipping already processed user_pk: 4101526799
# Skipping already processed user_pk: 57134925480
# Skipping already processed user_pk: 7110119859
# Skipping already processed user_pk: 45973235365
# Skipping already processed user_pk: 23892885731
# Skipping already processed user_pk: 5414246071
# Skipping already processed user_pk: 63898265323
# Skipping already processed user_pk: 49217848656
# Skipping already processed user_pk: 63755679763
# Skipping already processed user_pk: 6183498679
# Skipping already processed user_pk: 12419747506
# Skipping already processed user_pk: 7089106811
# Skipping already processed user_pk: 16649455672
# Skipping already processed user_pk: 13716603759
# Skipping already processed user_pk: 9286544853
# Skipping already processed user_pk: 48216385478
# Skipping already processed user_pk: 19447934733
# Skipping already processed user_pk: 2119410443
# Skipping already processed user_pk: 233100538
# Skipping already processed user_pk: 3550563850
# Skipping already processed user_pk: 3951697405
# Skipping already processed user_pk: 37331467134
# Skipping already processed user_pk: 8892085995
# Skipping already processed user_pk: 57545201235
# Skipping already processed user_pk: 1519226780
# Skipping already processed user_pk: 1550538887
# Skipping already processed user_pk: 8132769464
# Skipping already processed user_pk: 71714032050
# Skipping already processed user_pk: 72060499545
# Skipping already processed user_pk: 419645352
# Skipping already processed user_pk: 7166434913
# Skipping already processed user_pk: 59682271500
# Skipping already processed user_pk: 2087102267
# Skipping already processed user_pk: 286032284
# Skipping already processed user_pk: 3059565878
# Skipping already processed user_pk: 3497264969
# Skipping already processed user_pk: 195771167
# Skipping already processed user_pk: 1960967305
# Skipping already processed user_pk: 49575421696
# Skipping already processed user_pk: 54168964824
# Skipping already processed user_pk: 60702276177
# Skipping already processed user_pk: 72129851173
# 704306572 exotica6777
# Fetching followers for user_pk: 63087475282
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 54825569898 alcidestorres36
# Fetching followers for user_pk: 69363420116
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 72125315413 godover116
# Fetching followers for user_pk: 72301425466
# Pagina: 1
# Processing batch of 1 followers
# 37285436747 koma.ngmudani
# Fetching followers for user_pk: 72104652792
# Pagina: 1
# Processing batch of 1 followers
# 55272725859 madanthaper
# Fetching followers for user_pk: 70232465897
# Pagina: 1
# Processing batch of 1 followers
# 63508882002 sitaramchaudhary189
# Fetching followers for user_pk: 69521814173
# Pagina: 1
# Processing batch of 1 followers
# 42795228756 allahbaksh.shaik
# Fetching followers for user_pk: 63079179568
# Pagina: 1
# Pagina: 2
# Pagina: 3
# Processing batch of 49 followers
# 43923664314 black_h.k
# Fetching followers for user_pk: 63159820776
# Pagina: 1
# Processing batch of 1 followers
# 52827436975 shazia.qureshi.18400
# Fetching followers for user_pk: 71578327312
# Pagina: 1
# Processing batch of 6 followers
# 53203785335 suresh7029babu
# Fetching followers for user_pk: 70623990627
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 28339710041 nora.eng.100
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[372], line 12, in get_threads_userpk(username)
#      11 try:
# ---> 12     user_id_key_value = re.search('"user_id":"(\\d+)",', response.text).group()
#      13     user_id = re.search('\\d+', user_id_key_value).group()
#
# AttributeError: 'NoneType' object has no attribute 'group'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[383], line 34
#      32 username= dff[dff["follower_pk"] == int(user_pk)]["follower_username"].unique()[0]
#      33 print(user_pk,username )
# ---> 34 threads_user_pk = get_threads_userpk(str(username))
#      35 results = fetch_followers(threads_user_pk,user_pk)
#      36 if results is None:
#
# Cell In[372], line 15, in get_threads_userpk(username)
#      13     user_id = re.search('\\d+', user_id_key_value).group()
#      14 except:
# ---> 15     raise Exception()
#      16 return user_id
#
# Exception:

# %%
df1 = pd.read_csv(csv_file)
df_count= df1.drop_duplicates().groupby("user_pk").count()
print(df_count.shape)
df_count
# Out:
# (912, 4)
#              follower_pk  follower_username  follower_count  \
# user_pk
# 341164               670                670             670
# 688855                25                 25              25
# 755757                25                 25              25
# 1091690               25                 25              25
# 1953696              175                175             175
# ...                  ...                ...             ...
# 72060499545            1                  0               0
# 72092570887            1                  0               0
# 72125315413            1                  0               0
# 72129851173            1                  0               0
# 72493755585            1                  0               0
#
#              user_threads_userpk
# user_pk
# 341164                       670
# 688855                        25
# 755757                        25
# 1091690                       25
# 1953696                      175
# ...                          ...
# 72060499545                    1
# 72092570887                    1
# 72125315413                    1
# 72129851173                    1
# 72493755585                    1
#
# [912 rows x 4 columns]
