# %%
import logging
import pandas as pd
import os
import json
import time

# %%
with open("session.txt", "r") as f:
    sessionid = f.read()

# %%
headers_for_html_fetching = {
            'Authority': 'www.threads.net',
            'Accept': (
                'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;'
                'q=0.8,application/signed-exchange;v=b3;q=0.7'
            ),
            'Accept-Language': 'en-US,en;q=0.9',
            'Cache-Control': 'no-cache',
            'Content-Type': 'application/x-www-form-urlencoded',
            'Origin': 'https://www.threads.net',
            'Pragma': 'no-cache',
            'Referer': 'https://www.instagram.com',
            'Sec-Fetch-Dest': 'document',
            'Sec-Fetch-Mode': 'navigate',
            'Sec-Fetch-Site': 'cross-site',
            'Sec-Fetch-User': '?1',
            'Upgrade-Insecure-Requests': '1',
            'User-Agent': (
                'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) '
                'AppleWebKit/605.1.15 (KHTML, like Gecko) Version/11.1.2 Safari/605.1.15'
            ),
        }

# %%
import requests

def getuserfollowers(userid, after):

	url = "https://threads-api4.p.rapidapi.com/api/user/followers"

	querystring = {"user_id":userid,"end_cursor":after}

	# headers = {
	# 	"x-rapidapi-key": "33597f1514msh76f2ee2bf3e48abp12819cjsn0b3bbf51a993",
	# 	"x-rapidapi-host": "threads-api4.p.rapidapi.com"
	# }

	headers = {
		'x-rapidapi-key': "110a6c40e2msh84b7d831ac51c42p16225bjsna1e5d1776e12",
		'x-rapidapi-host': "threads-api4.p.rapidapi.com"
	}
 
	response = requests.get(url, headers=headers, params=querystring)
	if response.json()["message"].__contains__("You have exceeded the MONTHLY quota for Requests on your current plan"):
		raise Exception()
	return response.json()

# getuserfollowers("1172237643", "0")

# %%
import re
def get_threads_userpk(username:str):
    cookies = {
            "sessionid": sessionid
    }
    response = requests.get(
                url=f'https://www.threads.net/@{username}',
                headers=headers_for_html_fetching,
                cookies=cookies
            )
    try:
        if "viewer does not follow private user" in response.text:
            return None
        user_id_key_value = re.search('"user_id":"(\\d+)",', response.text).group()
        user_id = re.search('\\d+', user_id_key_value).group()
    except:
        raise Exception()
    return user_id

get_threads_userpk("foudebamba")

# %%
dff = pd.read_csv("followers_Artificial_Intelligence.csv")
dff[dff["follower_pk"]==69655371289]#["follower_username"].unique()[0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, user_pk, follower_pk, follower_username, follower_count]
# Index: []

# %%
from retrieve_data_by_query import RetrieveDataByQuery
t = RetrieveDataByQuery(sessionid=sessionid)
# t.retrieve_follower_by_userid_after("69655371289","0")

# %%
# query = "Artificial Intelligence"

# %%
def get_follower_data(data: list):
    try:
        return [
            {
                "pk": node.get("pk", ""),
                "username": node.get("username", ""),
                "follower_count": node.get("follower_count", "")
            }
            for d in data
            if (node := d.get("node", {}))
        ]
    except Exception as e:
        raise RuntimeError(f"Errore durante l'elaborazione dei dati dei follower: {e}")


progress_tracker = {}
filejson = "progress24.json"

def save_progress(userid: str, batch_number: int, results: list):
    """Salva il batch_number corrente e i risultati ottenuti per un determinato userid."""
    progress_tracker[userid] = {"batch_number": batch_number, "results": results}
    with open(filejson, "w") as f:
        json.dump(progress_tracker, f)

def load_progress(userid: str):
    """Carica il batch_number e i risultati salvati per un determinato userid."""
    try:
        with open(filejson, "r") as f:
            data = json.load(f)
            return data.get(userid, {"batch_number": 1, "results": []})
    except (FileNotFoundError, json.JSONDecodeError):
        return {"batch_number": 1, "results": []}
def remove_progress(userid: str):
    """Rimuove il progresso salvato per un determinato userid."""
    try:
        with open(filejson, "r") as f:
            data = json.load(f)
        
        if userid in data:
            del data[userid]
            with open(filejson, "w") as f:
                json.dump(data, f)
    except (FileNotFoundError, json.JSONDecodeError):
        pass
    
def get_all_follower(userid: str):
    progress = load_progress(userid)
    batch_number = progress["batch_number"]
    results = progress["results"]
    allpk = [res["pk"] for res in results]
    try:
        has_next_page = True
        while has_next_page:
            try:
                print("Pagina:", batch_number)
                # time.sleep(2)
                response = t.retrieve_follower_by_userid_after(userid, str(25 * batch_number-1))
                # response = getuserfollowe(userid, str(25 * batch_number-1))
                batch_number += 1
                data = response.get("data", {}).get("fetch__XDTUserDict", {}).get("followers", {})
                if data.get("edges", []) == []:
                    return [{
                        "pk": userid,
                        "username": None,
                        "follower_count": None
                    }]
                d_out = get_follower_data(data.get("edges", []))
                for res in d_out:
                    if res["pk"] in allpk:
                        remove_progress(userid)
                        return results
                    allpk.append(res["pk"])
                results.extend(d_out)
                
                has_next_page = data.get("page_info", {}).get("has_next_page", False)
                
                # Salva il progresso dopo ogni batch
                save_progress(userid, batch_number, results)
                
            except Exception as e:
                save_progress(userid, batch_number, results)  # Salva il batch e i risultati in caso di errore
                raise RuntimeError(f"Errore nel recupero della paginazione dei follower: {e}")
    
    except Exception as e:
        save_progress(userid, batch_number, results)  # Salva il batch e i risultati in caso di errore generale
        raise RuntimeError(f"Errore generale nel recupero dei follower per l'utente {userid}: {e}")
    remove_progress(userid)
    return results




def get_post_data(posts: list):
    results = []
    for post in posts:
        dati = post["node"]["thread"]["thread_items"]
        for p in dati:
            d = p['post']
            if int(d.get("like_count", 0)) < 100:
                continue
            userpk = d.get("user", {}).get("pk", "")
            caption = d.get("caption", {})
            caption_text = caption.get("text", "") if caption else ""
            if caption_text == "":
                continue
            results.append({
                "pk": d.get("pk", ""),
                "user_pk": userpk,
                "caption": caption_text,
                "like_count": int(d.get("like_count", 0)),
                "taken_at": d.get("taken_at", "")
            })
    return results

# %%
# results = []
# response = t.retrieve_thread_by_query(query)
# data = response.get("data", {}).get("searchResults", {})
# results.extend(get_post_data(data.get("edges", [])))
# has_next_page = data.get("page_info", {}).get("has_next_page", False)
# after = data.get("page_info", {}).get("end_cursor")
# i = 1000

# while has_next_page and i > 0:
#     response = t.retrieve_thread_by_query_after(query, after)
#     data = response.get("data", {}).get("searchResults", {})
#     results.extend(get_post_data(data.get("edges", [])))
#     has_next_page = data.get("page_info", {}).get("has_next_page", False)
#     after = data.get("page_info", {}).get("end_cursor")
#     i -= 1

# # Creazione del DataFrame
# df = pd.DataFrame(results)
# df.shape

# %%
# df.drop_duplicates(inplace=True)
# df['taken_at'] = pd.to_datetime(df['taken_at'], unit='s')
# df.to_csv("data.csv", index=False)

# %%
df = pd.read_csv("followers_Artificial_Intelligence4.csv")
df['follower_pk'] = df['follower_pk'].astype(str)
unique_user_pk = df['follower_pk'].unique()
len(unique_user_pk)
# Out:
# 3908

# %%
def load_processed_users(file_path):
    if os.path.exists(file_path):
        logging.info(f"Loading processed users from {file_path}")
        df = pd.read_csv(file_path)
        df['user_pk'] = df['user_pk'].astype(str)
        return set(df['user_pk'].tolist())
    return set()

def save_to_csv(df, file_path):
    try:
        if os.path.exists(file_path):
            df.to_csv(file_path, mode='a', header=False, index=False)
        else:
            df.to_csv(file_path, index=False)
        logging.info(f"Saved {len(df)} records to {file_path}")
    except Exception as e:
        logging.error(f"Error saving data to {file_path}: {e}")
        
csv_file = "followers_followers_Artificial_Intelligence4.csv"
processed_users = load_processed_users(csv_file)

# %%
len(processed_users)
# Out:
# 487

# %%
print(len(unique_user_pk))
unique_user_pk = unique_user_pk[unique_user_pk != "339473819"]
unique_user_pk = unique_user_pk[unique_user_pk != "1796326818"]
unique_user_pk = unique_user_pk[unique_user_pk != "1615352406"]
unique_user_pk = unique_user_pk[unique_user_pk != "270060044"]
unique_user_pk = unique_user_pk[unique_user_pk != "50242480845"]
unique_user_pk = unique_user_pk[unique_user_pk != "5342005343"]
unique_user_pk = unique_user_pk[unique_user_pk != "59464226701"]
unique_user_pk = unique_user_pk[unique_user_pk != "54036973294"]
unique_user_pk = unique_user_pk[unique_user_pk != "61348668946"]

unique_user_pk = unique_user_pk[unique_user_pk != "1615352406"]
unique_user_pk = unique_user_pk[unique_user_pk != "1615352406"]
unique_user_pk = unique_user_pk[unique_user_pk != "1615352406"]
unique_user_pk = unique_user_pk[unique_user_pk != "1615352406"]


  

print(len(unique_user_pk))
# Out:
# 3908
# 3901

# %%
def fetch_followers(pk,user_pk):
    print(f"Fetching followers for user_pk: {pk}")
    try:
        follower_data = get_all_follower(pk)
        return [
            {
                "user_pk": user_pk,
                "follower_pk": follower["pk"],
                "follower_username": follower["username"],
                "follower_count": follower["follower_count"],
                "user_threads_userpk": pk
            }
            for follower in follower_data
        ]
    except Exception as e:
        logging.error(f"Error fetching followers for {pk}: {e}")
        return None



follower_list = []
batch_size = 1


print("Starting follower data collection")
for user_pk in unique_user_pk:
    if user_pk in processed_users:
        print(f"Skipping already processed user_pk: {user_pk}")
        continue

    processed_users.update([user_pk])
    username= dff[dff["follower_pk"] == int(user_pk)]["follower_username"].unique()[0]
    print(user_pk, username)
    threads_user_pk = get_threads_userpk(str(username))
    if threads_user_pk == None:
        follower_list.extend([{
                "user_pk": user_pk,
                "follower_pk": None,
                "follower_username": None,
                "follower_count": None,
                "user_threads_userpk": None
            }
        ]
        )
        continue
    
    results = fetch_followers(threads_user_pk,user_pk)
    if results is None:
        break
    follower_list.extend(results)
    
    if follower_list:
        print(f"Processing batch of {len(follower_list)} followers")
        follower_df = pd.DataFrame(follower_list)
        save_to_csv(follower_df, csv_file)
        follower_list = []

if follower_list:
    print(f"Saving remaining {len(follower_list)} followers")
    follower_df = pd.DataFrame(follower_list)   
    save_to_csv(follower_df, csv_file)

print("Follower data collection completed")
# Out:
# Starting follower data collection
# Skipping already processed user_pk: 8355663179
# Skipping already processed user_pk: 66413130051
# Skipping already processed user_pk: 1916332480
# Skipping already processed user_pk: 7367652668
# Skipping already processed user_pk: 8034646076
# Skipping already processed user_pk: 7675464652
# Skipping already processed user_pk: 36171059450
# Skipping already processed user_pk: 60779511081
# Skipping already processed user_pk: 8956526740
# Skipping already processed user_pk: 22191948667
# Skipping already processed user_pk: 284674309
# Skipping already processed user_pk: 196428294
# Skipping already processed user_pk: 46571631322
# Skipping already processed user_pk: 65611717460
# Skipping already processed user_pk: 53284207
# Skipping already processed user_pk: 34395151369
# Skipping already processed user_pk: 12783756741
# Skipping already processed user_pk: 59182125214
# Skipping already processed user_pk: 28650618226
# Skipping already processed user_pk: 4030816819
# Skipping already processed user_pk: 1791508579
# Skipping already processed user_pk: 474378997
# Skipping already processed user_pk: 6965004661
# Skipping already processed user_pk: 2265130162
# Skipping already processed user_pk: 53657715366
# Skipping already processed user_pk: 66267430814
# Skipping already processed user_pk: 53015986734
# Skipping already processed user_pk: 47661844
# Skipping already processed user_pk: 1933827742
# Skipping already processed user_pk: 31731756409
# Skipping already processed user_pk: 283876444
# Skipping already processed user_pk: 8095146210
# Skipping already processed user_pk: 856642499
# Skipping already processed user_pk: 52849561827
# Skipping already processed user_pk: 29441382
# Skipping already processed user_pk: 48349518053
# Skipping already processed user_pk: 8210001453
# Skipping already processed user_pk: 50725588879
# Skipping already processed user_pk: 7453606200
# Skipping already processed user_pk: 1943515890
# Skipping already processed user_pk: 177639134
# Skipping already processed user_pk: 66041334252
# Skipping already processed user_pk: 3978467691
# Skipping already processed user_pk: 55388460296
# Skipping already processed user_pk: 59542980945
# Skipping already processed user_pk: 53616386863
# Skipping already processed user_pk: 44810096578
# Skipping already processed user_pk: 4483280107
# Skipping already processed user_pk: 4838431987
# Skipping already processed user_pk: 51647775330
# Skipping already processed user_pk: 34253993761
# Skipping already processed user_pk: 316606955
# Skipping already processed user_pk: 8530793713
# Skipping already processed user_pk: 26509483
# Skipping already processed user_pk: 1555305470
# Skipping already processed user_pk: 1671931439
# Skipping already processed user_pk: 56805583029
# Skipping already processed user_pk: 2270678073
# Skipping already processed user_pk: 9707964967
# Skipping already processed user_pk: 1302995711
# Skipping already processed user_pk: 44293452781
# Skipping already processed user_pk: 12491561551
# Skipping already processed user_pk: 8272686583
# Skipping already processed user_pk: 5692050442
# Skipping already processed user_pk: 6233850242
# Skipping already processed user_pk: 4576502966
# Skipping already processed user_pk: 49380679082
# Skipping already processed user_pk: 46850319679
# Skipping already processed user_pk: 67206616412
# Skipping already processed user_pk: 5900658382
# Skipping already processed user_pk: 5364275723
# Skipping already processed user_pk: 52227561705
# Skipping already processed user_pk: 8583696684
# Skipping already processed user_pk: 8393612771
# Skipping already processed user_pk: 180865765
# Skipping already processed user_pk: 5785789001
# Skipping already processed user_pk: 31440939271
# Skipping already processed user_pk: 4267013486
# Skipping already processed user_pk: 283075893
# Skipping already processed user_pk: 43778924007
# Skipping already processed user_pk: 4670076052
# Skipping already processed user_pk: 50505277542
# Skipping already processed user_pk: 5449182350
# Skipping already processed user_pk: 22849679646
# Skipping already processed user_pk: 25671701
# Skipping already processed user_pk: 14797812615
# Skipping already processed user_pk: 2071171386
# Skipping already processed user_pk: 1089240904
# Skipping already processed user_pk: 53008034
# Skipping already processed user_pk: 10720199689
# Skipping already processed user_pk: 64283392840
# Skipping already processed user_pk: 64107699837
# Skipping already processed user_pk: 2247381438
# Skipping already processed user_pk: 316577913
# Skipping already processed user_pk: 271563952
# Skipping already processed user_pk: 48789360140
# Skipping already processed user_pk: 5698612047
# Skipping already processed user_pk: 47819694
# Skipping already processed user_pk: 1511374231
# Skipping already processed user_pk: 7228768779
# Skipping already processed user_pk: 54191906324
# Skipping already processed user_pk: 14650354860
# Skipping already processed user_pk: 63131502483
# Skipping already processed user_pk: 44302995961
# Skipping already processed user_pk: 2109477019
# Skipping already processed user_pk: 47912346
# Skipping already processed user_pk: 55116878046
# Skipping already processed user_pk: 51859199080
# Skipping already processed user_pk: 308132603
# Skipping already processed user_pk: 339220237
# Skipping already processed user_pk: 58412002294
# Skipping already processed user_pk: 5864060398
# Skipping already processed user_pk: 5676550781
# Skipping already processed user_pk: 28604100009
# Skipping already processed user_pk: 44215142306
# Skipping already processed user_pk: 60899020593
# Skipping already processed user_pk: 45866820
# Skipping already processed user_pk: 59118498398
# Skipping already processed user_pk: 2709274020
# Skipping already processed user_pk: 53388854618
# Skipping already processed user_pk: 9043447880
# Skipping already processed user_pk: 7319929595
# Skipping already processed user_pk: 48771037475
# Skipping already processed user_pk: 59059121060
# Skipping already processed user_pk: 15731085467
# Skipping already processed user_pk: 54863818241
# Skipping already processed user_pk: 49410743090
# Skipping already processed user_pk: 61739283495
# Skipping already processed user_pk: 276708495
# Skipping already processed user_pk: 61921315477
# Skipping already processed user_pk: 66598072906
# Skipping already processed user_pk: 519472454
# Skipping already processed user_pk: 29306981592
# Skipping already processed user_pk: 10225345566
# Skipping already processed user_pk: 53042877383
# Skipping already processed user_pk: 524658953
# Skipping already processed user_pk: 51333731236
# Skipping already processed user_pk: 1421430528
# Skipping already processed user_pk: 5491703799
# Skipping already processed user_pk: 46878061975
# Skipping already processed user_pk: 7138547454
# Skipping already processed user_pk: 1435830699
# Skipping already processed user_pk: 58388023452
# Skipping already processed user_pk: 2162761913
# Skipping already processed user_pk: 29081559476
# Skipping already processed user_pk: 191617982
# Skipping already processed user_pk: 7691774216
# Skipping already processed user_pk: 6664464066
# Skipping already processed user_pk: 9416918
# Skipping already processed user_pk: 4297530435
# Skipping already processed user_pk: 55932807019
# Skipping already processed user_pk: 1336234766
# Skipping already processed user_pk: 7042154592
# Skipping already processed user_pk: 6139043598
# Skipping already processed user_pk: 64728516348
# Skipping already processed user_pk: 2202909685
# Skipping already processed user_pk: 247208078
# Skipping already processed user_pk: 6322692715
# Skipping already processed user_pk: 4358240983
# Skipping already processed user_pk: 1621910885
# Skipping already processed user_pk: 48253336486
# Skipping already processed user_pk: 2134261310
# Skipping already processed user_pk: 28469176159
# Skipping already processed user_pk: 145926110
# Skipping already processed user_pk: 2219243201
# Skipping already processed user_pk: 266142037
# Skipping already processed user_pk: 175116842
# Skipping already processed user_pk: 46451652735
# Skipping already processed user_pk: 55218653578
# Skipping already processed user_pk: 20707836
# Skipping already processed user_pk: 204420063
# Skipping already processed user_pk: 50166941207
# Skipping already processed user_pk: 52497808132
# Skipping already processed user_pk: 53600541143
# Skipping already processed user_pk: 11705789112
# Skipping already processed user_pk: 49987206845
# Skipping already processed user_pk: 65661485858
# Skipping already processed user_pk: 59536222093
# Skipping already processed user_pk: 336333064
# Skipping already processed user_pk: 53858851080
# Skipping already processed user_pk: 143723954
# Skipping already processed user_pk: 11674336944
# Skipping already processed user_pk: 322146907
# Skipping already processed user_pk: 5799904309
# Skipping already processed user_pk: 59546463403
# Skipping already processed user_pk: 1721464828
# Skipping already processed user_pk: 3102947475
# Skipping already processed user_pk: 60998160708
# Skipping already processed user_pk: 4296346117
# Skipping already processed user_pk: 1168729544
# Skipping already processed user_pk: 175234350
# Skipping already processed user_pk: 648688341
# Skipping already processed user_pk: 62835116484
# Skipping already processed user_pk: 67240917204
# Skipping already processed user_pk: 49721402036
# Skipping already processed user_pk: 63163639081
# Skipping already processed user_pk: 20015795760
# Skipping already processed user_pk: 1728121160
# Skipping already processed user_pk: 338215653
# Skipping already processed user_pk: 21273778760
# Skipping already processed user_pk: 269715219
# Skipping already processed user_pk: 19691548869
# Skipping already processed user_pk: 14228329718
# Skipping already processed user_pk: 54564910248
# Skipping already processed user_pk: 56885567481
# Skipping already processed user_pk: 186356391
# Skipping already processed user_pk: 6675050
# Skipping already processed user_pk: 58744905578
# Skipping already processed user_pk: 66749390946
# Skipping already processed user_pk: 2024521783
# Skipping already processed user_pk: 18980172377
# Skipping already processed user_pk: 3434592869
# Skipping already processed user_pk: 46109587145
# Skipping already processed user_pk: 67448496603
# Skipping already processed user_pk: 61898443940
# Skipping already processed user_pk: 8293962407
# Skipping already processed user_pk: 47859795099
# Skipping already processed user_pk: 66902292011
# Skipping already processed user_pk: 13997163
# Skipping already processed user_pk: 283209325
# Skipping already processed user_pk: 2224783741
# Skipping already processed user_pk: 3295030965
# Skipping already processed user_pk: 30489996723
# Skipping already processed user_pk: 1783209140
# Skipping already processed user_pk: 6535156088
# Skipping already processed user_pk: 66916378638
# Skipping already processed user_pk: 52900678850
# Skipping already processed user_pk: 51560217
# Skipping already processed user_pk: 48683834637
# Skipping already processed user_pk: 59962888447
# Skipping already processed user_pk: 7640923736
# Skipping already processed user_pk: 143969188
# Skipping already processed user_pk: 43095702875
# Skipping already processed user_pk: 65847034292
# Skipping already processed user_pk: 8530232728
# Skipping already processed user_pk: 9547617443
# Skipping already processed user_pk: 48992167991
# Skipping already processed user_pk: 2993708677
# Skipping already processed user_pk: 27032363072
# Skipping already processed user_pk: 33765333374
# Skipping already processed user_pk: 56955129983
# Skipping already processed user_pk: 67039004850
# Skipping already processed user_pk: 60296013529
# Skipping already processed user_pk: 58768840660
# Skipping already processed user_pk: 26241676376
# Skipping already processed user_pk: 67060898693
# Skipping already processed user_pk: 54584106237
# Skipping already processed user_pk: 63934748594
# Skipping already processed user_pk: 52694822548
# Skipping already processed user_pk: 334593279
# Skipping already processed user_pk: 56840330601
# Skipping already processed user_pk: 1272419297
# Skipping already processed user_pk: 58018150135
# Skipping already processed user_pk: 4008697435
# Skipping already processed user_pk: 207899509
# Skipping already processed user_pk: 8678248459
# Skipping already processed user_pk: 65116545643
# Skipping already processed user_pk: 67031925126
# Skipping already processed user_pk: 3552168319
# Skipping already processed user_pk: 8073727763
# Skipping already processed user_pk: 255236081
# Skipping already processed user_pk: 176303329
# Skipping already processed user_pk: 67038171463
# Skipping already processed user_pk: 65207988432
# Skipping already processed user_pk: 64013194675
# Skipping already processed user_pk: 50948223426
# Skipping already processed user_pk: 1387291175
# Skipping already processed user_pk: 10452858639
# Skipping already processed user_pk: 269341036
# Skipping already processed user_pk: 62727655619
# Skipping already processed user_pk: 60928219300
# Skipping already processed user_pk: 5670903179
# Skipping already processed user_pk: 51192801417
# Skipping already processed user_pk: 66066540795
# Skipping already processed user_pk: 3182172455
# Skipping already processed user_pk: 1582781073
# Skipping already processed user_pk: 13110778
# Skipping already processed user_pk: 1520624123
# Skipping already processed user_pk: 7904260633
# Skipping already processed user_pk: 4560273382
# Skipping already processed user_pk: 1309234429
# Skipping already processed user_pk: 67042851649
# Skipping already processed user_pk: 8608028480
# Skipping already processed user_pk: 64293418425
# Skipping already processed user_pk: 1247194066
# Skipping already processed user_pk: 229753677
# Skipping already processed user_pk: 8224780921
# Skipping already processed user_pk: 66254224118
# Skipping already processed user_pk: 55600274763
# Skipping already processed user_pk: 66318036541
# Skipping already processed user_pk: 7179024016
# Skipping already processed user_pk: 66461542235
# Skipping already processed user_pk: 12771861520
# Skipping already processed user_pk: 2087273895
# Skipping already processed user_pk: 6082784657
# Skipping already processed user_pk: 26308566
# Skipping already processed user_pk: 3647906677
# Skipping already processed user_pk: 1454552065
# Skipping already processed user_pk: 436471101
# Skipping already processed user_pk: 50301464034
# Skipping already processed user_pk: 13824130263
# Skipping already processed user_pk: 228424059
# Skipping already processed user_pk: 1596085642
# Skipping already processed user_pk: 3272782995
# Skipping already processed user_pk: 3793671249
# Skipping already processed user_pk: 14453931873
# Skipping already processed user_pk: 1383596154
# Skipping already processed user_pk: 54103268295
# Skipping already processed user_pk: 4106625965
# Skipping already processed user_pk: 7991717242
# Skipping already processed user_pk: 21869576
# Skipping already processed user_pk: 104834768
# Skipping already processed user_pk: 322650036
# Skipping already processed user_pk: 62946589204
# Skipping already processed user_pk: 573016647
# Skipping already processed user_pk: 1471009603
# Skipping already processed user_pk: 56662256391
# Skipping already processed user_pk: 4735021901
# Skipping already processed user_pk: 60353520187
# Skipping already processed user_pk: 64676347528
# Skipping already processed user_pk: 244149538
# Skipping already processed user_pk: 2128255882
# Skipping already processed user_pk: 188906531
# Skipping already processed user_pk: 58402260356
# Skipping already processed user_pk: 38296948877
# Skipping already processed user_pk: 461483630
# Skipping already processed user_pk: 3272726486
# Skipping already processed user_pk: 7413102434
# Skipping already processed user_pk: 64465815606
# Skipping already processed user_pk: 61099011391
# Skipping already processed user_pk: 1960481682
# Skipping already processed user_pk: 54859306967
# Skipping already processed user_pk: 1449720703
# Skipping already processed user_pk: 66984205682
# Skipping already processed user_pk: 55933445682
# Skipping already processed user_pk: 42478200
# Skipping already processed user_pk: 5864410925
# Skipping already processed user_pk: 9041439065
# Skipping already processed user_pk: 58703841718
# Skipping already processed user_pk: 6983681456
# Skipping already processed user_pk: 1149017028
# Skipping already processed user_pk: 13517392715
# Skipping already processed user_pk: 46205027712
# Skipping already processed user_pk: 44238212
# Skipping already processed user_pk: 67200655162
# Skipping already processed user_pk: 6734480039
# Skipping already processed user_pk: 10800111878
# Skipping already processed user_pk: 14188130519
# Skipping already processed user_pk: 1695935206
# Skipping already processed user_pk: 260695310
# Skipping already processed user_pk: 33197532491
# Skipping already processed user_pk: 1602903896
# Skipping already processed user_pk: 11100273175
# Skipping already processed user_pk: 6197379665
# Skipping already processed user_pk: 57940433842
# Skipping already processed user_pk: 61280114991
# Skipping already processed user_pk: 54520372042
# Skipping already processed user_pk: 1568264550
# Skipping already processed user_pk: 10199178354
# Skipping already processed user_pk: 55386453
# Skipping already processed user_pk: 542505935
# Skipping already processed user_pk: 3117845374
# Skipping already processed user_pk: 38453188245
# Skipping already processed user_pk: 6670260702
# Skipping already processed user_pk: 2878345931
# Skipping already processed user_pk: 11399026707
# Skipping already processed user_pk: 57695789805
# Skipping already processed user_pk: 34736747936
# Skipping already processed user_pk: 3059020612
# Skipping already processed user_pk: 58652336185
# Skipping already processed user_pk: 45281655236
# Skipping already processed user_pk: 66850046269
# Skipping already processed user_pk: 66704080809
# Skipping already processed user_pk: 59715332106
# Skipping already processed user_pk: 55739145836
# Skipping already processed user_pk: 61549857512
# Skipping already processed user_pk: 66663437624
# Skipping already processed user_pk: 41524633721
# Skipping already processed user_pk: 5352079752
# Skipping already processed user_pk: 587372320
# Skipping already processed user_pk: 192951500
# Skipping already processed user_pk: 64944713491
# Skipping already processed user_pk: 1333028794
# Skipping already processed user_pk: 1488281650
# Skipping already processed user_pk: 52335627
# Skipping already processed user_pk: 2982740787
# Skipping already processed user_pk: 50904693128
# Skipping already processed user_pk: 411154891
# Skipping already processed user_pk: 66522236989
# Skipping already processed user_pk: 58042442657
# Skipping already processed user_pk: 4662429255
# Skipping already processed user_pk: 60062379572
# Skipping already processed user_pk: 5781246396
# Skipping already processed user_pk: 555984101
# Skipping already processed user_pk: 62962457632
# Skipping already processed user_pk: 50444082634
# Skipping already processed user_pk: 66024351463
# Skipping already processed user_pk: 2107168678
# Skipping already processed user_pk: 6198015827
# Skipping already processed user_pk: 48754793205
# Skipping already processed user_pk: 225951929
# Skipping already processed user_pk: 8333135485
# Skipping already processed user_pk: 40914132699
# Skipping already processed user_pk: 61871555574
# Skipping already processed user_pk: 2868729104
# Skipping already processed user_pk: 54052964980
# Skipping already processed user_pk: 66530909581
# Skipping already processed user_pk: 67200254578
# Skipping already processed user_pk: 59067952217
# Skipping already processed user_pk: 6665269486
# Skipping already processed user_pk: 1459555170
# Skipping already processed user_pk: 8399573688
# Skipping already processed user_pk: 4705116193
# Skipping already processed user_pk: 1461344133
# Skipping already processed user_pk: 29171237
# Skipping already processed user_pk: 66812475361
# Skipping already processed user_pk: 58812783335
# Skipping already processed user_pk: 63375298043
# Skipping already processed user_pk: 229291695
# Skipping already processed user_pk: 61988004072
# Skipping already processed user_pk: 1327361715
# Skipping already processed user_pk: 510610419
# Skipping already processed user_pk: 1462893212
# Skipping already processed user_pk: 47918927
# Skipping already processed user_pk: 44946129658
# Skipping already processed user_pk: 3502294655
# Skipping already processed user_pk: 1271917592
# Skipping already processed user_pk: 2093085162
# Skipping already processed user_pk: 326592680
# Skipping already processed user_pk: 64344517284
# Skipping already processed user_pk: 9979366657
# Skipping already processed user_pk: 191538969
# Skipping already processed user_pk: 61717991711
# Skipping already processed user_pk: 18000948777
# Skipping already processed user_pk: 4608040303
# Skipping already processed user_pk: 67063560166
# Skipping already processed user_pk: 67001681683
# Skipping already processed user_pk: 65791568390
# Skipping already processed user_pk: 181390713
# Skipping already processed user_pk: 6082317422
# Skipping already processed user_pk: 50372389707
# Skipping already processed user_pk: 2209042249
# Skipping already processed user_pk: 213639949
# Skipping already processed user_pk: 275002796
# Skipping already processed user_pk: 5583196
# Skipping already processed user_pk: 3497435637
# Skipping already processed user_pk: 227038197
# Skipping already processed user_pk: 65783098707
# Skipping already processed user_pk: 55550676424
# Skipping already processed user_pk: 66790721857
# Skipping already processed user_pk: 1102751035
# Skipping already processed user_pk: 6642580210
# Skipping already processed user_pk: 8483633357
# Skipping already processed user_pk: 1770915709
# Skipping already processed user_pk: 25129297955
# Skipping already processed user_pk: 41895724411
# Skipping already processed user_pk: 853762266
# Skipping already processed user_pk: 31805781266
# Skipping already processed user_pk: 60609710290
# Skipping already processed user_pk: 66751941124
# Skipping already processed user_pk: 1274773056
# Skipping already processed user_pk: 66665299776
# Skipping already processed user_pk: 3025557465
# Skipping already processed user_pk: 59521583370
# Skipping already processed user_pk: 49758545856
# Skipping already processed user_pk: 6191844500
# Skipping already processed user_pk: 34685644029
# Skipping already processed user_pk: 3030206669
# Skipping already processed user_pk: 521847534
# Skipping already processed user_pk: 58392731822
# Skipping already processed user_pk: 145170113
# Skipping already processed user_pk: 56707576440
# Skipping already processed user_pk: 1546247313
# Skipping already processed user_pk: 9143309216
# Skipping already processed user_pk: 33323464
# Skipping already processed user_pk: 12011500266
# Skipping already processed user_pk: 1384369292
# Skipping already processed user_pk: 993805475
# Skipping already processed user_pk: 306271723
# Skipping already processed user_pk: 414915118
# Skipping already processed user_pk: 479999469
# Skipping already processed user_pk: 17296461
# Skipping already processed user_pk: 50833767170
# Skipping already processed user_pk: 595306588
# Skipping already processed user_pk: 247410260
# Skipping already processed user_pk: 7367091055
# 1829723230 joannabonnell
# Fetching followers for user_pk: 67036577176
# Pagina: 1
# Processing batch of 1 followers
# 62607513800 alaisanagudi
# Fetching followers for user_pk: 65589244175
# Pagina: 1
# Processing batch of 1 followers
# 55065379238 gloria.rumble
# Fetching followers for user_pk: 65423514014
# Pagina: 1
# Processing batch of 18 followers
# 285912734 andislyy
# Fetching followers for user_pk: 63380617256
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 175387504 followbrittneyrenae
# Fetching followers for user_pk: 64379989067
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 1697178620 skyyrichardson
# Fetching followers for user_pk: 64245073996
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 905900137 ajarrett91
# Fetching followers for user_pk: 65021921234
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 64710145411 addie121010
# Fetching followers for user_pk: 66852637359
# Pagina: 1
# Processing batch of 1 followers
# 10594612 _ro0skie
# Fetching followers for user_pk: 64495102280
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 53768187590 wridayy
# 1943333 annebarringer
# Fetching followers for user_pk: 63468376629
# Pagina: 1
# Pagina: 2
# Processing batch of 26 followers
# 16777930 kaitydav
# 51570747582 fofucoin
# Fetching followers for user_pk: 66863436093
# Pagina: 1
# Pagina: 2
# Processing batch of 26 followers
# 2269012733 mkultra8710
# Fetching followers for user_pk: 66458044117
# Pagina: 1
# Processing batch of 1 followers
# 34031318 m.goddessintheflesh
# Fetching followers for user_pk: 63606240738
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 4078201078 angelleneee
# Fetching followers for user_pk: 64110315447
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 297625758 allys31
# Fetching followers for user_pk: 63425866051
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 6908229322 godofarson
# Fetching followers for user_pk: 66216126820
# Pagina: 1
# Processing batch of 10 followers
# 61281098331 abaszadeh445
# Fetching followers for user_pk: 67023666684
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 2348498 lunarscorpio_
# Fetching followers for user_pk: 63630176545
# Pagina: 1
# Pagina: 2
# Pagina: 3
# Processing batch of 48 followers
# 6914545881 elisechristine_art
# Fetching followers for user_pk: 66645548840
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 6326293565 _kaayllee
# 50538360 talktomeee_niiice
# Fetching followers for user_pk: 65782369405
# Pagina: 1
# Pagina: 2
# Processing batch of 26 followers
# 218923034 rootworkenthusiast_90
# Fetching followers for user_pk: 63306891102
# Pagina: 1
# Pagina: 2
# Processing batch of 24 followers
# 2174287303 elchuntinegro
# 3320885975 grierlarsen
# 32975141 4eva_gr8tful
# 65611655508 sarabarela10
# 52124423635 _noparkingonly
# Fetching followers for user_pk: 63414331267
# Pagina: 1
# Pagina: 2
# Processing batch of 29 followers
# 29308005392 trial_card_human_version
# Fetching followers for user_pk: 63252943681
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 1553914888 k_ylerayner
# 34578037914 kingwhalshyfyre
# Fetching followers for user_pk: 65661924617
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 2297590444 octavio_vg1
# 1519129993 cosmocoocoo
# Fetching followers for user_pk: 63384631779
# Pagina: 1
# Pagina: 2
# Processing batch of 28 followers
# 2121845454 lifeofnate.__
# Fetching followers for user_pk: 66259641234
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 2298207680 trinity_veee
# Fetching followers for user_pk: 66690064182
# Pagina: 1
# Pagina: 2
# Processing batch of 33 followers
# 1733846619 tyler_ett
# Fetching followers for user_pk: 65434202002
# Pagina: 1
# Processing batch of 1 followers
# 6431781940 lync3_
# Fetching followers for user_pk: 65897592674
# Pagina: 1
# Processing batch of 12 followers
# 58303082974 sumannegi20404
# Fetching followers for user_pk: 63088729774
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 62704175471 sassycougar001
# Fetching followers for user_pk: 64360383374
# Pagina: 1
# Processing batch of 1 followers
# 34714569781 ms.tiffanykt.1
# Fetching followers for user_pk: 63394798056
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 62456121247 mohena208
# Fetching followers for user_pk: 63582117675
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 10404110378 mancavemasters
# Fetching followers for user_pk: 66210423508
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 439655046 angelicaboqvist
# Fetching followers for user_pk: 65172177328
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 1700361731 rahim_raj
# 65681309076 savagelylovelegend
# Fetching followers for user_pk: 66995133721
# Pagina: 1
# Processing batch of 2 followers
# 56536037488 itsmedana.rose
# Fetching followers for user_pk: 66657121717
# Pagina: 1
# Processing batch of 1 followers
# 51805093849 nonfarmerdan
# Fetching followers for user_pk: 65255058628
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 60161531984 bigjimmyaura
# Fetching followers for user_pk: 63775452216
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 67042193553 rickimannell
# Fetching followers for user_pk: 67041193355
# Pagina: 1
# Processing batch of 1 followers
# 1598822179 bodegapope
# Fetching followers for user_pk: 63440176120
# Pagina: 1
# Pagina: 2
# Processing batch of 24 followers
# 56672028584 christil695
# Fetching followers for user_pk: 62880511395
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 33760339605 sbllaw1794
# Fetching followers for user_pk: 63485265516
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 44684643676 hhhevnnn
# Fetching followers for user_pk: 63394974702
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 6451139339 rettaman
# 441628297 _alexxlove
# Fetching followers for user_pk: 67008858349
# Pagina: 1
# Pagina: 2
# Processing batch of 26 followers
# 1604473482 sophiakuttu
# Fetching followers for user_pk: 63951273958
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 3032227517 marcsky2016
# Fetching followers for user_pk: 63617424715
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 619220337 _cheyparsons_
# Fetching followers for user_pk: 65211480996
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 63259387939 treep_ng
# Fetching followers for user_pk: 65669088982
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 56401512095 leanallllthewayin
# Fetching followers for user_pk: 66409767083
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 3285445511 patel_kelvin_
# Fetching followers for user_pk: 63426777618
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 54094629581 c_l_musicdj
# Fetching followers for user_pk: 66456403615
# Pagina: 1
# Processing batch of 15 followers
# 48651880391 itsherriej.t_galore
# Fetching followers for user_pk: 63407581030
# Pagina: 1
# Pagina: 2
# Processing batch of 24 followers
# 2933943623 roselle_dacumos
# 47366891037 crazie_rona26
# Fetching followers for user_pk: 64133069191
# Pagina: 1
# Processing batch of 2 followers
# 49954354668 bunzo.maghanoy
# Fetching followers for user_pk: 66544049493
# Pagina: 1
# Processing batch of 25 followers
# 60067567314 brittney_saigexx
# Fetching followers for user_pk: 65784950234
# Pagina: 1
# Pagina: 2
# Processing batch of 24 followers
# 1450662323 ben.vd
# Fetching followers for user_pk: 66881690438
# Pagina: 1
# Processing batch of 1 followers
# 63557571725 shinelovia
# Fetching followers for user_pk: 67011859613
# Pagina: 1
# Pagina: 2
# Processing batch of 24 followers
# 1333840693 jonny_stap
# Fetching followers for user_pk: 66698920092
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 1139686094 matilde_nov
# Fetching followers for user_pk: 64387039524
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 3289451324 _sinnabunz
# Fetching followers for user_pk: 63339387705
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 1338632526 lulu1oo8
# 10343672938 grace.amancio
# Fetching followers for user_pk: 66480097365
# Pagina: 1
# Processing batch of 13 followers
# 51089562246 dear_prec
# Fetching followers for user_pk: 63860072088
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 3195593624 rheena0527
# Fetching followers for user_pk: 65770245534
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 66663810980 orororrrrrri
# Fetching followers for user_pk: 66833326735
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 735356578 eichjeii
# Fetching followers for user_pk: 63497458079
# Pagina: 1
# Processing batch of 21 followers
# 64674176067 mputt.anteuu
# Fetching followers for user_pk: 66989620596
# Pagina: 1
# Processing batch of 1 followers
# 66873002970 jennakali.w8so1n
# Fetching followers for user_pk: 66669250777
# Pagina: 1
# Processing batch of 2 followers
# 51609952043 chadash_moses
# Fetching followers for user_pk: 66155492597
# Pagina: 1
# Pagina: 2
# Processing batch of 35 followers
# 55568860687 janeyarodgers
# Fetching followers for user_pk: 66322160180
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 67042281387 cayhadatba
# Fetching followers for user_pk: 67044553083
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 66881226397 wrinjaya
# Fetching followers for user_pk: 66835846329
# Pagina: 1
# Processing batch of 10 followers
# 8420920839 kumaresen.nair
# Fetching followers for user_pk: 66735015406
# Pagina: 1
# Pagina: 2
# Processing batch of 27 followers
# 45140847416 chtw.ts
# Fetching followers for user_pk: 65536151650
# Pagina: 1
# Processing batch of 1 followers
# 52303025851 cherisangels2
# Fetching followers for user_pk: 65538245312
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 52534538688 bolton_de_boy
# Fetching followers for user_pk: 63434001989
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 3909548842 msroulettema82
# Fetching followers for user_pk: 63303123541
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 1128193780 gdrbluewolf
# Fetching followers for user_pk: 63912185411
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 66669082763 nco24885
# Fetching followers for user_pk: 67204128619
# Pagina: 1
# Processing batch of 10 followers
# 4721688928 helenalwrites
# Fetching followers for user_pk: 63319545410
# Pagina: 1
# Pagina: 2
# Pagina: 3
# Processing batch of 50 followers
# 31482808450 sanset_4568
# Fetching followers for user_pk: 65204121568
# Pagina: 1
# Processing batch of 24 followers
# 67000989002 axh29724
# Fetching followers for user_pk: 66663811172
# Pagina: 1
# Processing batch of 1 followers
# 67202177641 glovanna.horton
# Fetching followers for user_pk: 67051208062
# Pagina: 1
# Processing batch of 1 followers
# 66665658213 vaybaxatha
# Fetching followers for user_pk: 67205872416
# Pagina: 1
# Pagina: 2
# Processing batch of 24 followers
# 67059408031 vayhaqha
# Fetching followers for user_pk: 67013059858
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 66987630172 vagbacagja
# Fetching followers for user_pk: 66839270076
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 222425682 jacubinthecut
# Fetching followers for user_pk: 65064149978
# Pagina: 1
# Pagina: 2
# Processing batch of 24 followers
# 7813918561 thejashree_hegde
# Fetching followers for user_pk: 66720839873
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 36806424575 kornelia.r28
# 37310343702 stephanielbrogdon
# Fetching followers for user_pk: 63484274977
# Pagina: 1
# Pagina: 2
# Processing batch of 26 followers
# 44762739381 b.kent.mitchell.5
# Fetching followers for user_pk: 63098315329
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 66748340110 pochowahine
# Fetching followers for user_pk: 66739078589
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 1262668296 zaetrillz
# Fetching followers for user_pk: 63445985045
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 9935423202 akhilendra_pratap01
# 48688432901 myohmymyleeah
# Fetching followers for user_pk: 66113047940
# Pagina: 1
# Pagina: 2
# Processing batch of 26 followers
# 58154347080 _the_sound_of_words
# Fetching followers for user_pk: 67039073208
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 62222450152 kalyope.eko.98
# Fetching followers for user_pk: 66291134207
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 50735711035 misshaitiacademy
# Fetching followers for user_pk: 63384830173
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 50132366 tashymanifests
# Fetching followers for user_pk: 64227299357
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 57283118475 _jazzmulabae
# Fetching followers for user_pk: 67019651186
# Pagina: 1
# Processing batch of 18 followers
# 6807204049 wtxleandro_junior
# Fetching followers for user_pk: 66986462121
# Pagina: 1
# Processing batch of 17 followers
# 30847173975 thatgirl.jeanne
# Fetching followers for user_pk: 66678705939
# Pagina: 1
# Processing batch of 1 followers
# 9447607627 friscooneil
# Fetching followers for user_pk: 62818847497
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 15323342 p00nracoon
# Fetching followers for user_pk: 66822702164
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 45993836773 el_erik_miquiztli
# Fetching followers for user_pk: 63369439816
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 65136183642 mhel8605
# Fetching followers for user_pk: 65964462983
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 3231229976 argybargy70
# Fetching followers for user_pk: 66866107917
# Pagina: 1
# Processing batch of 1 followers
# 1496341555 mrsadriangraham
# Fetching followers for user_pk: 63321040016
# Pagina: 1
# Processing batch of 14 followers
# 290945229 sairatoor
# Fetching followers for user_pk: 63472585050
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 1479658950 rosendo.salazarr
# Fetching followers for user_pk: 63250824970
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 31122675382 dianaauburn1
# Fetching followers for user_pk: 63127117432
# Pagina: 1
# Processing batch of 7 followers
# 9438592061 rachodonnell_xo
# Fetching followers for user_pk: 63045926611
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 6886652197 chrisgale7372
# 57283262373 itsreyss_
# 54987395 hannahela1n3
# 52477848043 ___keloadamz
# Fetching followers for user_pk: 66863444043
# Pagina: 1
# Processing batch of 4 followers
# 66679241698 cristirobnett
# Fetching followers for user_pk: 66851901146
# Pagina: 1
# Processing batch of 2 followers
# 65738861410 danielhaeuszer
# Fetching followers for user_pk: 66992505613
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 2981887337 sr.vincent
# Fetching followers for user_pk: 63343568557
# Pagina: 1
# Pagina: 2
# Processing batch of 25 followers
# 8299862586 marie_alonzo1313
# Fetching followers for user_pk: 66851970735
# Pagina: 1
# Processing batch of 1 followers
# 8918950356 lynds_brown
# 7063632435 life_is_beautiful.6
# Fetching followers for user_pk: 63327723866
# Pagina: 1
# Processing batch of 5 followers
# 2001467657 monasupah
# Fetching followers for user_pk: 67034216981
# Pagina: 1
# Processing batch of 21 followers
# 8944388382 jess___93s
# 60839252426 damnedanddelusional
# Fetching followers for user_pk: 63376935585
# Pagina: 1
# Pagina: 2
# Processing batch of 26 followers
# 222303727 andrei.butnarasu
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[289], line 14, in get_threads_userpk(username)
#      13     return None
# ---> 14 user_id_key_value = re.search('"user_id":"(\\d+)",', response.text).group()
#      15 user_id = re.search('\\d+', user_id_key_value).group()
#
# AttributeError: 'NoneType' object has no attribute 'group'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[300], line 34
#      32 username= dff[dff["follower_pk"] == int(user_pk)]["follower_username"].unique()[0]
#      33 print(user_pk, username)
# ---> 34 threads_user_pk = get_threads_userpk(str(username))
#      35 if threads_user_pk == None:
#      36     follower_list.extend([{
#      37             "user_pk": user_pk,
#      38             "follower_pk": None,
#    (...)
#      43     ]
#      44     )
#
# Cell In[289], line 17, in get_threads_userpk(username)
#      15     user_id = re.search('\\d+', user_id_key_value).group()
#      16 except:
# ---> 17     raise Exception()
#      18 return user_id
#
# Exception:

# %%
df1 = pd.read_csv(csv_file)
df_count= df1.drop_duplicates().groupby("user_pk").count()
print(df_count.shape)
df_count
# Out:
# (625, 4)
#              follower_pk  follower_username  follower_count  \
# user_pk
# 1943333               25                 25              25
# 2348498               48                 48              48
# 5583196                0                  0               0
# 6675050               49                 49              49
# 9416918                0                  0               0
# ...                  ...                ...             ...
# 67200655162            1                  1               1
# 67202177641            1                  0               0
# 67206616412            0                  0               0
# 67240917204            1                  0               0
# 67448496603            1                  0               0
#
#              user_threads_userpk
# user_pk
# 1943333                       25
# 2348498                       48
# 5583196                        0
# 6675050                       49
# 9416918                        0
# ...                          ...
# 67200655162                    1
# 67202177641                    1
# 67206616412                    0
# 67240917204                    1
# 67448496603                    1
#
# [625 rows x 4 columns]
