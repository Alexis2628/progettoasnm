# %%
import logging
import pandas as pd
import os
import numpy as np

# %%
from retrieve_post_by_userid import RetrievePostByUserId
t = RetrievePostByUserId(sessionid="")

# %%
def get_post_data(data,userid): 
    post_list = [] 
    if data is not None and data["data"] is not None and data["data"]["mediaData"] is not None and data["data"]["mediaData"]["edges"] is not None: 
        edges = data["data"]["mediaData"]["edges"] 
        if edges == []: 
            return [ 
                { 
                    "id": None, 
                    "post_pk": None, 
                    "caption_text": None, 
                    "like_count": None, 
                    "taken_at":None, 
                    "username": None, 
                    "user_pk": userid, 
                    "quote_count": None, 
                    "repost_count": None, 
                    "reshare_count": None, 
                } 
            ] 
        else: 
            try: 
                for edge in edges: 
                    thread_items = edge["node"]["thread_items"] 
                    for thread_item in thread_items: 
                        post = thread_item["post"] 
                        if post["caption"] is None or post["user"] is None or post["text_post_app_info"] is None: 
                            current_post = { 
                            "id": post.get("id",""), 
                            "post_pk": post.get("pk",""), 
                            "caption_text": None if post["caption"] is None else post.get("caption",{}).get("text",""), 
                            "like_count": post.get("like_count",""), 
                            "taken_at": post.get("taken_at",""), 
                            "username": None if post["user"] is None else post.get("user",{}).get("username",""), 
                            "user_pk": post.get("user",{}).get("pk",""), 
                            "quote_count": None if post["text_post_app_info"] is None else post["text_post_app_info"].get("quote_count",0), 
                            "repost_count": None if post["text_post_app_info"] is None else post["text_post_app_info"].get("repost_count",0), 
                            "reshare_count": None if post["text_post_app_info"] is None else post["text_post_app_info"].get("reshare_count",0), 
                        } 
                        else: 
                            current_post = { 
                                "id": post.get("id",""), 
                                "post_pk": post.get("pk",""), 
                                "caption_text": post.get("caption",{}).get("text",""), 
                                "like_count": post.get("like_count",""), 
                                "taken_at": post.get("taken_at",""), 
                                "username": post.get("user",{}).get("username",""), 
                                "user_pk": post.get("user",{}).get("pk",""), 
                                "quote_count": post["text_post_app_info"].get("quote_count",0), 
                                "repost_count": post["text_post_app_info"].get("repost_count",0), 
                                "reshare_count": post["text_post_app_info"].get("reshare_count",0), 
                            } 
                        post_list.append(current_post) 
                return post_list 
            except Exception as e: 
                raise RuntimeError(f"Errore durante l'elaborazione dei dati dei follower: {e}") 
    if data["errors"]: 
        for error in data["errors"]: 
            if error.get("message") == "execution error" and error.get("description") == "cannot see user": 
                return [ 
                        { 
                            "id": None, 
                            "post_pk": None, 
                            "caption_text": None, 
                            "like_count": None, 
                            "taken_at":None, 
                            "username": None, 
                            "user_pk": userid, 
                            "quote_count": None, 
                            "repost_count": None, 
                            "reshare_count": None, 
                        } 
                    ] 
    return []

def get_all_post(userid: str): 
    results = [] 
    try: 
        response = t.retrieve_thread_by_userid(userid) 
        d_out = get_post_data(response,userid) 
        results.extend(d_out) 
    except Exception as e: 
        print(response) 
        raise RuntimeError(f"Errore generale nel recupero dei follower per l'utente {userid}: {e}") 
    return results

# %%
# df = pd.read_csv("data_chat_gpt.csv")
# df['user_pk'] = df['user_pk'].astype(str)
# unique_user_pk = df['user_pk'].unique()
# len(unique_user_pk)

# %%
df2 = pd.read_csv("followers_ChatGPT_2.csv")
df2['follower_pk'] = df2['follower_pk'].astype(str)
unique_user = df2['follower_pk'].unique()
len(unique_user)
# Out:
# 4074

# %%
# unique_user = np.concatenate([unique_user_pk, unique_user_pk2])
# len(unique_user)

# %%
def load_processed_users(file_path):
    if os.path.exists(file_path):
        logging.info(f"Loading processed users from {file_path}")
        df = pd.read_csv(file_path)
        df['user_pk'] = df['user_pk'].astype(str)
        return set(df['user_pk'].tolist())
    return set()

def save_to_csv(df, file_path):
    try:
        if os.path.exists(file_path):
            df.to_csv(file_path, mode='a', header=False, index=False)
        else:
            df.to_csv(file_path, index=False)
        logging.info(f"Saved {len(df)} records to {file_path}")
    except Exception as e:
        logging.error(f"Error saving data to {file_path}: {e}")
        
csv_file = "post_data_chatgpt2.csv"
processed_users = load_processed_users(csv_file)

# %%
len(processed_users)
# Out:
# 2037

# %%
unique_user = unique_user[unique_user != "2018738310"]
unique_user = unique_user[unique_user != "1109450"]

# %%
import pandas as pd
i = len(processed_users)
for user in unique_user:
     if user not in processed_users:
        # print(user)
        i+=1
        posts = get_all_post(user)
        final_df = pd.DataFrame(posts)
        save_to_csv(final_df, csv_file)
        print(f"Processati {i} utenti su {len(unique_user)}")

print("Processo completato!")
# Out:
# Processati 2038 utenti su 4072
# Processati 2039 utenti su 4072
# Processati 2040 utenti su 4072
# Processati 2041 utenti su 4072
# Processati 2042 utenti su 4072
# Processati 2043 utenti su 4072
# Processati 2044 utenti su 4072
# Processati 2045 utenti su 4072
# Processati 2046 utenti su 4072
# Processati 2047 utenti su 4072
# Processati 2048 utenti su 4072
# Processati 2049 utenti su 4072
# Processati 2050 utenti su 4072
# Processati 2051 utenti su 4072
# Processati 2052 utenti su 4072
# Processati 2053 utenti su 4072
# Processati 2054 utenti su 4072
# Processati 2055 utenti su 4072
# Processati 2056 utenti su 4072
# Processati 2057 utenti su 4072
# Processati 2058 utenti su 4072
# Processati 2059 utenti su 4072
# Processati 2060 utenti su 4072
# Processati 2061 utenti su 4072
# Processati 2062 utenti su 4072
# Processati 2063 utenti su 4072
# Processati 2064 utenti su 4072
# Processati 2065 utenti su 4072
# Processati 2066 utenti su 4072
# Processati 2067 utenti su 4072
# Processati 2068 utenti su 4072
# Processati 2069 utenti su 4072
# Processati 2070 utenti su 4072
# Processati 2071 utenti su 4072
# Processati 2072 utenti su 4072
# Processati 2073 utenti su 4072
# Processati 2074 utenti su 4072
# Processati 2075 utenti su 4072
# Processati 2076 utenti su 4072
# Processati 2077 utenti su 4072
# Processati 2078 utenti su 4072
# Processati 2079 utenti su 4072
# Processati 2080 utenti su 4072
# Processati 2081 utenti su 4072
# Processati 2082 utenti su 4072
# Processati 2083 utenti su 4072
# Processati 2084 utenti su 4072
# Processati 2085 utenti su 4072
# Processati 2086 utenti su 4072
# Processati 2087 utenti su 4072
# Processati 2088 utenti su 4072
# Processati 2089 utenti su 4072
# Processati 2090 utenti su 4072
# Processati 2091 utenti su 4072
# Processati 2092 utenti su 4072
# Processati 2093 utenti su 4072
# Processati 2094 utenti su 4072
# Processati 2095 utenti su 4072
# Processati 2096 utenti su 4072
# Processati 2097 utenti su 4072
# Processati 2098 utenti su 4072
# Processati 2099 utenti su 4072
# Processati 2100 utenti su 4072
# Processati 2101 utenti su 4072
# Processati 2102 utenti su 4072
# Processati 2103 utenti su 4072
# Processati 2104 utenti su 4072
# Processati 2105 utenti su 4072
# Processati 2106 utenti su 4072
# Processati 2107 utenti su 4072
# Processati 2108 utenti su 4072
# Processati 2109 utenti su 4072
# Processati 2110 utenti su 4072
# Processati 2111 utenti su 4072
# Processati 2112 utenti su 4072
# Processati 2113 utenti su 4072
# Processati 2114 utenti su 4072
# Processati 2115 utenti su 4072
# Processati 2116 utenti su 4072
# Processati 2117 utenti su 4072
# Processati 2118 utenti su 4072
# Processati 2119 utenti su 4072
# Processati 2120 utenti su 4072
# Processati 2121 utenti su 4072
# Processati 2122 utenti su 4072
# Processati 2123 utenti su 4072
# Processati 2124 utenti su 4072
# Processati 2125 utenti su 4072
# Processati 2126 utenti su 4072
# Processati 2127 utenti su 4072
# Processati 2128 utenti su 4072
# Processati 2129 utenti su 4072
# Processati 2130 utenti su 4072
# Processati 2131 utenti su 4072
# Processati 2132 utenti su 4072
# Processati 2133 utenti su 4072
# Processati 2134 utenti su 4072
# Processati 2135 utenti su 4072
# Processati 2136 utenti su 4072
# Processati 2137 utenti su 4072
# Processati 2138 utenti su 4072
# Processati 2139 utenti su 4072
# Processati 2140 utenti su 4072
# Processati 2141 utenti su 4072
# Processati 2142 utenti su 4072
# Processati 2143 utenti su 4072
# Processati 2144 utenti su 4072
# Processati 2145 utenti su 4072
# Processati 2146 utenti su 4072
# Processati 2147 utenti su 4072
# Processati 2148 utenti su 4072
# Processati 2149 utenti su 4072
# Processati 2150 utenti su 4072
# Processati 2151 utenti su 4072
# Processati 2152 utenti su 4072
# Processati 2153 utenti su 4072
# Processati 2154 utenti su 4072
# Processati 2155 utenti su 4072
# Processati 2156 utenti su 4072
# Processati 2157 utenti su 4072
# Processati 2158 utenti su 4072
# Processati 2159 utenti su 4072
# Processati 2160 utenti su 4072
# Processati 2161 utenti su 4072
# Processati 2162 utenti su 4072
# Processati 2163 utenti su 4072
# Processati 2164 utenti su 4072
# Processati 2165 utenti su 4072
# Processati 2166 utenti su 4072
# Processati 2167 utenti su 4072
# Processati 2168 utenti su 4072
# Processati 2169 utenti su 4072
# Processati 2170 utenti su 4072
# Processati 2171 utenti su 4072
# Processati 2172 utenti su 4072
# Processati 2173 utenti su 4072
# Processati 2174 utenti su 4072
# Processati 2175 utenti su 4072
# Processati 2176 utenti su 4072
# Processati 2177 utenti su 4072
# Processati 2178 utenti su 4072
# Processati 2179 utenti su 4072
# Processati 2180 utenti su 4072
# Processati 2181 utenti su 4072
# Processati 2182 utenti su 4072
# Processati 2183 utenti su 4072
# Processati 2184 utenti su 4072
# Processati 2185 utenti su 4072
# Processati 2186 utenti su 4072
# Processati 2187 utenti su 4072
# Processati 2188 utenti su 4072
# Processati 2189 utenti su 4072
# Processati 2190 utenti su 4072
# Processati 2191 utenti su 4072
# Processati 2192 utenti su 4072
# Processati 2193 utenti su 4072
# Processati 2194 utenti su 4072
# Processati 2195 utenti su 4072
# Processati 2196 utenti su 4072
# Processati 2197 utenti su 4072
# Processati 2198 utenti su 4072
# Processati 2199 utenti su 4072
# Processati 2200 utenti su 4072
# Processati 2201 utenti su 4072
# Processati 2202 utenti su 4072
# Processati 2203 utenti su 4072
# Processati 2204 utenti su 4072
# Processati 2205 utenti su 4072
# Processati 2206 utenti su 4072
# Processati 2207 utenti su 4072
# Processati 2208 utenti su 4072
# Processati 2209 utenti su 4072
# Processati 2210 utenti su 4072
# Processati 2211 utenti su 4072
# Processati 2212 utenti su 4072
# Processati 2213 utenti su 4072
# Processati 2214 utenti su 4072
# Processati 2215 utenti su 4072
# Processati 2216 utenti su 4072
# Processati 2217 utenti su 4072
# Processati 2218 utenti su 4072
# Processati 2219 utenti su 4072
# Processati 2220 utenti su 4072
# Processati 2221 utenti su 4072
# Processati 2222 utenti su 4072
# Processati 2223 utenti su 4072
# Processati 2224 utenti su 4072
# Processati 2225 utenti su 4072
# Processati 2226 utenti su 4072
# Processati 2227 utenti su 4072
# Processati 2228 utenti su 4072
# Processati 2229 utenti su 4072
# Processati 2230 utenti su 4072
# Processati 2231 utenti su 4072
# Processati 2232 utenti su 4072
# Processati 2233 utenti su 4072
# Processati 2234 utenti su 4072
# Processati 2235 utenti su 4072
# Processati 2236 utenti su 4072
# Processati 2237 utenti su 4072
# Processati 2238 utenti su 4072
# Processati 2239 utenti su 4072
# Processati 2240 utenti su 4072
# Processati 2241 utenti su 4072
# Processati 2242 utenti su 4072
# Processati 2243 utenti su 4072
# Processati 2244 utenti su 4072
# Processati 2245 utenti su 4072
# Processati 2246 utenti su 4072
# Processati 2247 utenti su 4072
# Processati 2248 utenti su 4072
# Processati 2249 utenti su 4072
# Processati 2250 utenti su 4072
# Processati 2251 utenti su 4072
# Processati 2252 utenti su 4072
# Processati 2253 utenti su 4072
# Processati 2254 utenti su 4072
# Processati 2255 utenti su 4072
# Processati 2256 utenti su 4072
# Processati 2257 utenti su 4072
# Processati 2258 utenti su 4072
# Processati 2259 utenti su 4072
# Processati 2260 utenti su 4072
# Processati 2261 utenti su 4072
# Processati 2262 utenti su 4072
# Processati 2263 utenti su 4072
# Processati 2264 utenti su 4072
# Processati 2265 utenti su 4072
# Processati 2266 utenti su 4072
# Processati 2267 utenti su 4072
# Processati 2268 utenti su 4072
# Processati 2269 utenti su 4072
# Processati 2270 utenti su 4072
# Processati 2271 utenti su 4072
# Processati 2272 utenti su 4072
# Processati 2273 utenti su 4072
# Processati 2274 utenti su 4072
# Processati 2275 utenti su 4072
# Processati 2276 utenti su 4072
# Processati 2277 utenti su 4072
# Processati 2278 utenti su 4072
# Processati 2279 utenti su 4072
# Processati 2280 utenti su 4072
# Processati 2281 utenti su 4072
# Processati 2282 utenti su 4072
# Processati 2283 utenti su 4072
# Processati 2284 utenti su 4072
# Processati 2285 utenti su 4072
# Processati 2286 utenti su 4072
# Processati 2287 utenti su 4072
# Processati 2288 utenti su 4072
# Processati 2289 utenti su 4072
# Processati 2290 utenti su 4072
# Processati 2291 utenti su 4072
# Processati 2292 utenti su 4072
# Processati 2293 utenti su 4072
# Processati 2294 utenti su 4072
# Processati 2295 utenti su 4072
# Processati 2296 utenti su 4072
# Processati 2297 utenti su 4072
# Processati 2298 utenti su 4072
# Processati 2299 utenti su 4072
# Processati 2300 utenti su 4072
# Processati 2301 utenti su 4072
# Processati 2302 utenti su 4072
# Processati 2303 utenti su 4072
# Processati 2304 utenti su 4072
# Processati 2305 utenti su 4072
# Processati 2306 utenti su 4072
# Processati 2307 utenti su 4072
# Processati 2308 utenti su 4072
# Processati 2309 utenti su 4072
# Processati 2310 utenti su 4072
# Processati 2311 utenti su 4072
# Processati 2312 utenti su 4072
# Processati 2313 utenti su 4072
# Processati 2314 utenti su 4072
# Processati 2315 utenti su 4072
# Processati 2316 utenti su 4072
# Processati 2317 utenti su 4072
# Processati 2318 utenti su 4072
# Processati 2319 utenti su 4072
# Processati 2320 utenti su 4072
# Processati 2321 utenti su 4072
# Processati 2322 utenti su 4072
# Processati 2323 utenti su 4072
# Processati 2324 utenti su 4072
# Processati 2325 utenti su 4072
# Processati 2326 utenti su 4072
# Processati 2327 utenti su 4072
# Processati 2328 utenti su 4072
# Processati 2329 utenti su 4072
# Processati 2330 utenti su 4072
# Processati 2331 utenti su 4072
# Processati 2332 utenti su 4072
# Processati 2333 utenti su 4072
# Processati 2334 utenti su 4072
# Processati 2335 utenti su 4072
# Processati 2336 utenti su 4072
# Processati 2337 utenti su 4072
# Processati 2338 utenti su 4072
# Processati 2339 utenti su 4072
# Processati 2340 utenti su 4072
# Processati 2341 utenti su 4072
# Processati 2342 utenti su 4072
# Processati 2343 utenti su 4072
# Processati 2344 utenti su 4072
# Processati 2345 utenti su 4072
# Processati 2346 utenti su 4072
# Processati 2347 utenti su 4072
# Processati 2348 utenti su 4072
# Processati 2349 utenti su 4072
# Processati 2350 utenti su 4072
# Processati 2351 utenti su 4072
# Processati 2352 utenti su 4072
# Processati 2353 utenti su 4072
# Processati 2354 utenti su 4072
# Processati 2355 utenti su 4072
# Processati 2356 utenti su 4072
# Processati 2357 utenti su 4072
# Processati 2358 utenti su 4072
# Processati 2359 utenti su 4072
# Processati 2360 utenti su 4072
# Processati 2361 utenti su 4072
# Processati 2362 utenti su 4072
# Processati 2363 utenti su 4072
# Processati 2364 utenti su 4072
# Processati 2365 utenti su 4072
# Processati 2366 utenti su 4072
# Processati 2367 utenti su 4072
# Processati 2368 utenti su 4072
# Processati 2369 utenti su 4072
# Processati 2370 utenti su 4072
# Processati 2371 utenti su 4072
# Processati 2372 utenti su 4072
# Processati 2373 utenti su 4072
# Processati 2374 utenti su 4072
# Processati 2375 utenti su 4072
# Processati 2376 utenti su 4072
# Processati 2377 utenti su 4072
# Processati 2378 utenti su 4072
# Processati 2379 utenti su 4072
# Processati 2380 utenti su 4072
# Processati 2381 utenti su 4072
# Processati 2382 utenti su 4072
# Processati 2383 utenti su 4072
# Processati 2384 utenti su 4072
# Processati 2385 utenti su 4072
# Processati 2386 utenti su 4072
# Processati 2387 utenti su 4072
# Processati 2388 utenti su 4072
# Processati 2389 utenti su 4072
# Processati 2390 utenti su 4072
# Processati 2391 utenti su 4072
# Processati 2392 utenti su 4072
# Processati 2393 utenti su 4072
# Processati 2394 utenti su 4072
# Processati 2395 utenti su 4072
# Processati 2396 utenti su 4072
# Processati 2397 utenti su 4072
# Processati 2398 utenti su 4072
# Processati 2399 utenti su 4072
# Processati 2400 utenti su 4072
# Processati 2401 utenti su 4072
# Processati 2402 utenti su 4072
# Processati 2403 utenti su 4072
# Processati 2404 utenti su 4072
# Processati 2405 utenti su 4072
# Processati 2406 utenti su 4072
# Processati 2407 utenti su 4072
# Processati 2408 utenti su 4072
# Processati 2409 utenti su 4072
# Processati 2410 utenti su 4072
# Processati 2411 utenti su 4072
# Processati 2412 utenti su 4072
# Processati 2413 utenti su 4072
# Processati 2414 utenti su 4072
# Processati 2415 utenti su 4072
# Processati 2416 utenti su 4072
# Processati 2417 utenti su 4072
# Processati 2418 utenti su 4072
# Processati 2419 utenti su 4072
# Processati 2420 utenti su 4072
# Processati 2421 utenti su 4072
# Processati 2422 utenti su 4072
# Processati 2423 utenti su 4072
# Processati 2424 utenti su 4072
# Processati 2425 utenti su 4072
# Processati 2426 utenti su 4072
# Processati 2427 utenti su 4072
# Processati 2428 utenti su 4072
# Processati 2429 utenti su 4072
# Processati 2430 utenti su 4072
# Processati 2431 utenti su 4072
# Processati 2432 utenti su 4072
# Processati 2433 utenti su 4072
# Processati 2434 utenti su 4072
# Processati 2435 utenti su 4072
# Processati 2436 utenti su 4072
# Processati 2437 utenti su 4072
# Processati 2438 utenti su 4072
# Processati 2439 utenti su 4072
# Processati 2440 utenti su 4072
# Processati 2441 utenti su 4072
# Processati 2442 utenti su 4072
# Processati 2443 utenti su 4072
# Processati 2444 utenti su 4072
# Processati 2445 utenti su 4072
# Processati 2446 utenti su 4072
# Processati 2447 utenti su 4072
# Processati 2448 utenti su 4072
# Processati 2449 utenti su 4072
# Processati 2450 utenti su 4072
# Processati 2451 utenti su 4072
# Processati 2452 utenti su 4072
# Processati 2453 utenti su 4072
# Processati 2454 utenti su 4072
# Processati 2455 utenti su 4072
# Processati 2456 utenti su 4072
# Processati 2457 utenti su 4072
# Processati 2458 utenti su 4072
# Processati 2459 utenti su 4072
# Processati 2460 utenti su 4072
# Processati 2461 utenti su 4072
# Processati 2462 utenti su 4072
# Processati 2463 utenti su 4072
# Processati 2464 utenti su 4072
# Processati 2465 utenti su 4072
# Processati 2466 utenti su 4072
# Processati 2467 utenti su 4072
# Processati 2468 utenti su 4072
# Processati 2469 utenti su 4072
# Processati 2470 utenti su 4072
# Processati 2471 utenti su 4072
# Processati 2472 utenti su 4072
# Processati 2473 utenti su 4072
# Processati 2474 utenti su 4072
# Processati 2475 utenti su 4072
# Processati 2476 utenti su 4072
# Processati 2477 utenti su 4072
# Processati 2478 utenti su 4072
# Processati 2479 utenti su 4072
# Processati 2480 utenti su 4072
# Processati 2481 utenti su 4072
# Processati 2482 utenti su 4072
# Processati 2483 utenti su 4072
# Processati 2484 utenti su 4072
# Processati 2485 utenti su 4072
# Processati 2486 utenti su 4072
# Processati 2487 utenti su 4072
# Processati 2488 utenti su 4072
# Processati 2489 utenti su 4072
# Processati 2490 utenti su 4072
# Processati 2491 utenti su 4072
# Processati 2492 utenti su 4072
# Processati 2493 utenti su 4072
# Processati 2494 utenti su 4072
# Processati 2495 utenti su 4072
# Processati 2496 utenti su 4072
# Processati 2497 utenti su 4072
# Processati 2498 utenti su 4072
# Processati 2499 utenti su 4072
# Processati 2500 utenti su 4072
# Processati 2501 utenti su 4072
# Processati 2502 utenti su 4072
# Processati 2503 utenti su 4072
# Processati 2504 utenti su 4072
# Processati 2505 utenti su 4072
# Processati 2506 utenti su 4072
# Processati 2507 utenti su 4072
# Processati 2508 utenti su 4072
# Processati 2509 utenti su 4072
# Processati 2510 utenti su 4072
# Processati 2511 utenti su 4072
# Processati 2512 utenti su 4072
# Processati 2513 utenti su 4072
# Processati 2514 utenti su 4072
# Processati 2515 utenti su 4072
# Processati 2516 utenti su 4072
# Processati 2517 utenti su 4072
# Processati 2518 utenti su 4072
# Processati 2519 utenti su 4072
# Processati 2520 utenti su 4072
# Processati 2521 utenti su 4072
# Processati 2522 utenti su 4072
# Processati 2523 utenti su 4072
# Processati 2524 utenti su 4072
# Processati 2525 utenti su 4072
# Processati 2526 utenti su 4072
# Processati 2527 utenti su 4072
# Processati 2528 utenti su 4072
# Processati 2529 utenti su 4072
# Processati 2530 utenti su 4072
# Processati 2531 utenti su 4072
# Processati 2532 utenti su 4072
# Processati 2533 utenti su 4072
# Processati 2534 utenti su 4072
# Processati 2535 utenti su 4072
# Processati 2536 utenti su 4072
# Processati 2537 utenti su 4072
# Processati 2538 utenti su 4072
# Processati 2539 utenti su 4072
# Processati 2540 utenti su 4072
# Processati 2541 utenti su 4072
# Processati 2542 utenti su 4072
# Processati 2543 utenti su 4072
# Processati 2544 utenti su 4072
# Processati 2545 utenti su 4072
# Processati 2546 utenti su 4072
# Processati 2547 utenti su 4072
# Processati 2548 utenti su 4072
# Processati 2549 utenti su 4072
# Processati 2550 utenti su 4072
# Processati 2551 utenti su 4072
# Processati 2552 utenti su 4072
# Processati 2553 utenti su 4072
# Processati 2554 utenti su 4072
# Processati 2555 utenti su 4072
# Processati 2556 utenti su 4072
# Processati 2557 utenti su 4072
# Processati 2558 utenti su 4072
# Processati 2559 utenti su 4072
# Processati 2560 utenti su 4072
# Processati 2561 utenti su 4072
# Processati 2562 utenti su 4072
# Processati 2563 utenti su 4072
# Processati 2564 utenti su 4072
# Processati 2565 utenti su 4072
# Processati 2566 utenti su 4072
# Processati 2567 utenti su 4072
# Processati 2568 utenti su 4072
# Processati 2569 utenti su 4072
# Processati 2570 utenti su 4072
# Processati 2571 utenti su 4072
# Processati 2572 utenti su 4072
# Processati 2573 utenti su 4072
# Processati 2574 utenti su 4072
# Processati 2575 utenti su 4072
# Processati 2576 utenti su 4072
# Processati 2577 utenti su 4072
# Processati 2578 utenti su 4072
# Processati 2579 utenti su 4072
# Processati 2580 utenti su 4072
# Processati 2581 utenti su 4072
# Processati 2582 utenti su 4072
# Processati 2583 utenti su 4072
# Processati 2584 utenti su 4072
# Processati 2585 utenti su 4072
# Processati 2586 utenti su 4072
# Processati 2587 utenti su 4072
# Processati 2588 utenti su 4072
# Processati 2589 utenti su 4072
# Processati 2590 utenti su 4072
# Processati 2591 utenti su 4072
# Processati 2592 utenti su 4072
# Processati 2593 utenti su 4072
# Processati 2594 utenti su 4072
# Processati 2595 utenti su 4072
# Processati 2596 utenti su 4072
# Processati 2597 utenti su 4072
# Processati 2598 utenti su 4072
# Processati 2599 utenti su 4072
# Processati 2600 utenti su 4072
# Processati 2601 utenti su 4072
# Processati 2602 utenti su 4072
# Processati 2603 utenti su 4072
# Processati 2604 utenti su 4072
# Processati 2605 utenti su 4072
# Processati 2606 utenti su 4072
# Processati 2607 utenti su 4072
# Processati 2608 utenti su 4072
# Processati 2609 utenti su 4072
# Processati 2610 utenti su 4072
# Processati 2611 utenti su 4072
# Processati 2612 utenti su 4072
# Processati 2613 utenti su 4072
# Processati 2614 utenti su 4072
# Processati 2615 utenti su 4072
# Processati 2616 utenti su 4072
# Processati 2617 utenti su 4072
# Processati 2618 utenti su 4072
# Processati 2619 utenti su 4072
# Processati 2620 utenti su 4072
# Processati 2621 utenti su 4072
# Processati 2622 utenti su 4072
# Processati 2623 utenti su 4072
# Processati 2624 utenti su 4072
# Processati 2625 utenti su 4072
# Processati 2626 utenti su 4072
# Processati 2627 utenti su 4072
# Processati 2628 utenti su 4072
# Processati 2629 utenti su 4072
# Processati 2630 utenti su 4072
# Processati 2631 utenti su 4072
# Processati 2632 utenti su 4072
# Processati 2633 utenti su 4072
# Processati 2634 utenti su 4072
# Processati 2635 utenti su 4072
# Processati 2636 utenti su 4072
# Processati 2637 utenti su 4072
# Processati 2638 utenti su 4072
# Processati 2639 utenti su 4072
# Processati 2640 utenti su 4072
# Processati 2641 utenti su 4072
# Processati 2642 utenti su 4072
# Processati 2643 utenti su 4072
# Processati 2644 utenti su 4072
# Processati 2645 utenti su 4072
# Processati 2646 utenti su 4072
# Processati 2647 utenti su 4072
# Processati 2648 utenti su 4072
# Processati 2649 utenti su 4072
# Processati 2650 utenti su 4072
# Processati 2651 utenti su 4072
# Processati 2652 utenti su 4072
# Processati 2653 utenti su 4072
# Processati 2654 utenti su 4072
# Processati 2655 utenti su 4072
# Processati 2656 utenti su 4072
# Processati 2657 utenti su 4072
# Processati 2658 utenti su 4072
# Processati 2659 utenti su 4072
# Processati 2660 utenti su 4072
# Processati 2661 utenti su 4072
# Processati 2662 utenti su 4072
# Processati 2663 utenti su 4072
# Processati 2664 utenti su 4072
# Processati 2665 utenti su 4072
# Processati 2666 utenti su 4072
# Processati 2667 utenti su 4072
# Processati 2668 utenti su 4072
# Processati 2669 utenti su 4072
# Processati 2670 utenti su 4072
# Processati 2671 utenti su 4072
# Processati 2672 utenti su 4072
# Processati 2673 utenti su 4072
# Processati 2674 utenti su 4072
# Processati 2675 utenti su 4072
# Processati 2676 utenti su 4072
# Processati 2677 utenti su 4072
# Processati 2678 utenti su 4072
# Processati 2679 utenti su 4072
# Processati 2680 utenti su 4072
# Processati 2681 utenti su 4072
# Processati 2682 utenti su 4072
# Processati 2683 utenti su 4072
# Processati 2684 utenti su 4072
# Processati 2685 utenti su 4072
# Processati 2686 utenti su 4072
# Processati 2687 utenti su 4072
# Processati 2688 utenti su 4072
# Processati 2689 utenti su 4072
# Processati 2690 utenti su 4072
# Processati 2691 utenti su 4072
# Processati 2692 utenti su 4072
# Processati 2693 utenti su 4072
# Processati 2694 utenti su 4072
# Processati 2695 utenti su 4072
# Processati 2696 utenti su 4072
# Processati 2697 utenti su 4072
# Processati 2698 utenti su 4072
# Processati 2699 utenti su 4072
# Processati 2700 utenti su 4072
# Processati 2701 utenti su 4072
# Processati 2702 utenti su 4072
# Processati 2703 utenti su 4072
# Processati 2704 utenti su 4072
# Processati 2705 utenti su 4072
# Processati 2706 utenti su 4072
# Processati 2707 utenti su 4072
# Processati 2708 utenti su 4072
# Processati 2709 utenti su 4072
# Processati 2710 utenti su 4072
# Processati 2711 utenti su 4072
# Processati 2712 utenti su 4072
# Processati 2713 utenti su 4072
# Processati 2714 utenti su 4072
# Processati 2715 utenti su 4072
# Processati 2716 utenti su 4072
# Processati 2717 utenti su 4072
# Processati 2718 utenti su 4072
# Processati 2719 utenti su 4072
# Processati 2720 utenti su 4072
# Processati 2721 utenti su 4072
# Processati 2722 utenti su 4072
# Processati 2723 utenti su 4072
# Processati 2724 utenti su 4072
# Processati 2725 utenti su 4072
# Processati 2726 utenti su 4072
# Processati 2727 utenti su 4072
# Processati 2728 utenti su 4072
# Processati 2729 utenti su 4072
# Processati 2730 utenti su 4072
# Processati 2731 utenti su 4072
# Processati 2732 utenti su 4072
# Processati 2733 utenti su 4072
# Processati 2734 utenti su 4072
# Processati 2735 utenti su 4072
# Processati 2736 utenti su 4072
# Processati 2737 utenti su 4072
# Processati 2738 utenti su 4072
# Processati 2739 utenti su 4072
# Processati 2740 utenti su 4072
# Processati 2741 utenti su 4072
# Processati 2742 utenti su 4072
# Processati 2743 utenti su 4072
# Processati 2744 utenti su 4072
# Processati 2745 utenti su 4072
# Processati 2746 utenti su 4072
# Processati 2747 utenti su 4072
# Processati 2748 utenti su 4072
# Processati 2749 utenti su 4072
# Processati 2750 utenti su 4072
# Processati 2751 utenti su 4072
# Processati 2752 utenti su 4072
# Processati 2753 utenti su 4072
# Processati 2754 utenti su 4072
# Processati 2755 utenti su 4072
# Processati 2756 utenti su 4072
# Processati 2757 utenti su 4072
# Processati 2758 utenti su 4072
# Processati 2759 utenti su 4072
# Processati 2760 utenti su 4072
# Processati 2761 utenti su 4072
# Processati 2762 utenti su 4072
# Processati 2763 utenti su 4072
# Processati 2764 utenti su 4072
# Processati 2765 utenti su 4072
# Processati 2766 utenti su 4072
# Processati 2767 utenti su 4072
# Processati 2768 utenti su 4072
# Processati 2769 utenti su 4072
# Processati 2770 utenti su 4072
# Processati 2771 utenti su 4072
# Processati 2772 utenti su 4072
# Processati 2773 utenti su 4072
# Processati 2774 utenti su 4072
# Processati 2775 utenti su 4072
# Processati 2776 utenti su 4072
# Processati 2777 utenti su 4072
# Processati 2778 utenti su 4072
# Processati 2779 utenti su 4072
# Processati 2780 utenti su 4072
# Processati 2781 utenti su 4072
# Processati 2782 utenti su 4072
# Processati 2783 utenti su 4072
# Processati 2784 utenti su 4072
# Processati 2785 utenti su 4072
# Processati 2786 utenti su 4072
# Processati 2787 utenti su 4072
# Processati 2788 utenti su 4072
# Processati 2789 utenti su 4072
# Processati 2790 utenti su 4072
# Processati 2791 utenti su 4072
# Processati 2792 utenti su 4072
# Processati 2793 utenti su 4072
# Processati 2794 utenti su 4072
# Processati 2795 utenti su 4072
# Processati 2796 utenti su 4072
# Processati 2797 utenti su 4072
# Processati 2798 utenti su 4072
# Processati 2799 utenti su 4072
# Processati 2800 utenti su 4072
# Processati 2801 utenti su 4072
# Processati 2802 utenti su 4072
# Processati 2803 utenti su 4072
# Processati 2804 utenti su 4072
# Processati 2805 utenti su 4072
# Processati 2806 utenti su 4072
# Processati 2807 utenti su 4072
# Processati 2808 utenti su 4072
# Processati 2809 utenti su 4072
# Processati 2810 utenti su 4072
# Processati 2811 utenti su 4072
# Processati 2812 utenti su 4072
# Processati 2813 utenti su 4072
# Processati 2814 utenti su 4072
# Processati 2815 utenti su 4072
# Processati 2816 utenti su 4072
# Processati 2817 utenti su 4072
# Processati 2818 utenti su 4072
# Processati 2819 utenti su 4072
# Processati 2820 utenti su 4072
# Processati 2821 utenti su 4072
# Processati 2822 utenti su 4072
# Processati 2823 utenti su 4072
# Processati 2824 utenti su 4072
# Processati 2825 utenti su 4072
# Processati 2826 utenti su 4072
# Processati 2827 utenti su 4072
# Processati 2828 utenti su 4072
# Processati 2829 utenti su 4072
# Processati 2830 utenti su 4072
# Processati 2831 utenti su 4072
# Processati 2832 utenti su 4072
# Processati 2833 utenti su 4072
# Processati 2834 utenti su 4072
# Processati 2835 utenti su 4072
# Processati 2836 utenti su 4072
# Processati 2837 utenti su 4072
# Processati 2838 utenti su 4072
# Processati 2839 utenti su 4072
# Processati 2840 utenti su 4072
# Processati 2841 utenti su 4072
# Processati 2842 utenti su 4072
# Processati 2843 utenti su 4072
# Processati 2844 utenti su 4072
# Processati 2845 utenti su 4072
# Processati 2846 utenti su 4072
# Processati 2847 utenti su 4072
# Processati 2848 utenti su 4072
# Processati 2849 utenti su 4072
# {'message': 'Attendi qualche minuto prima di riprovare.', 'require_login': True, 'igweb_rollout': True, 'status': 'fail'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 79, in get_all_post(userid)
#      78 response = t.retrieve_thread_by_userid(userid)
# ---> 79 d_out = get_post_data(response,userid)
#      80 results.extend(d_out)
#
# Cell In[61], line 3, in get_post_data(data, userid)
#       2 post_list = []
# ----> 3 if data is not None and data["data"] is not None and data["data"]["mediaData"] is not None and data["data"]["mediaData"]["edges"] is not None:
#       4     edges = data["data"]["mediaData"]["edges"]
#
# KeyError: 'data'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[68], line 7
#       4 if user not in processed_users:
#       5    # print(user)
#       6    i+=1
# ----> 7    posts = get_all_post(user)
#       8    final_df = pd.DataFrame(posts)
#       9    save_to_csv(final_df, csv_file)
#
# Cell In[61], line 83, in get_all_post(userid)
#      81 except Exception as e:
#      82     print(response)
# ---> 83     raise RuntimeError(f"Errore generale nel recupero dei follower per l'utente {userid}: {e}")
#      84 return results
#
# RuntimeError: Errore generale nel recupero dei follower per l'utente 70435800626: 'data'

# %%
df1 = pd.read_csv(csv_file).drop_duplicates()
print(df1.shape)
df1
# Out:
# (49328, 10)
#                                     id       post_pk  \
# 0      3556503364705235589_57666094056  3.556503e+18
# 1      3555730866451646099_57666094056  3.555731e+18
# 2      3555632212571112619_57666094056  3.555632e+18
# 3      3554870787011765397_57666094056  3.554871e+18
# 4      3554155796214168463_57666094056  3.554156e+18
# ...                                ...           ...
# 49323    3449431740732330571_651952269  3.449432e+18
# 49324    3443045977006356854_651952269  3.443046e+18
# 49325    3443047645903199298_651952269  3.443048e+18
# 49326    3430607806956154513_651952269  3.430608e+18
# 49327    3430706635235683530_651952269  3.430707e+18
#
#                                             caption_text  like_count  \
# 0            These cars just got roasted by ChatGPT! 🏎️😂       158.0
# 1      Sam Altman’s first reaction to DeepSeek’s open...        71.0
# 2      Meta AI’s latest upgrade allows it to remember...         8.0
# 3      👉 Comment “Editor” and we’ll send you the link...         4.0
# 4      From static to cinematic in one click 🎥\n\nRun...        73.0
# ...                                                  ...         ...
# 49323                                                NaN         5.0
# 49324  스친들아\n\n지난번 미국상사의 아들이 한국에 급히온다고\n원룸문의를 올린바있어\n...         5.0
# 49325  이어서\n새로운가족을 만났지만 너무나 위축되었는데\n인생의 첫도전을 한국에와서  시...         6.0
# 49326  스친들아\n\n급히 물어볼것이있어 지나치지말고\n의견구한다\n\n미국상사의 아들이 ...        12.0
# 49327                                   고마워스친들아 진짜 척척박사다         2.0
#
#            taken_at      username      user_pk  quote_count  repost_count  \
# 0      1.738188e+09  chatgptricks  57666094056          0.0          11.0
# 1      1.738096e+09  chatgptricks  57666094056          0.0           2.0
# 2      1.738084e+09  chatgptricks  57666094056          0.0           0.0
# 3      1.737994e+09  chatgptricks  57666094056          0.0           0.0
# 4      1.737908e+09  chatgptricks  57666094056          0.0           1.0
# ...             ...           ...          ...          ...           ...
# 49323  1.725424e+09     hidaisyhi    651952269          0.0           0.0
# 49324  1.724663e+09     hidaisyhi    651952269          0.0           0.0
# 49325  1.724663e+09     hidaisyhi    651952269          0.0           0.0
# 49326  1.723180e+09     hidaisyhi    651952269          0.0           1.0
# 49327  1.723192e+09     hidaisyhi    651952269          0.0           0.0
#
#        reshare_count
# 0                7.0
# 1               10.0
# 2                NaN
# 3                2.0
# 4                5.0
# ...              ...
# 49323            NaN
# 49324            NaN
# 49325            NaN
# 49326            NaN
# 49327            NaN
#
# [49328 rows x 10 columns]
