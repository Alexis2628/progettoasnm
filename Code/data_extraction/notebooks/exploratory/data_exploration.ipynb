# %% [markdown]
# # Esplorazione iniziale dei dati
#
# In questo notebook analizziamo i dataset raccolti dalle query **AI**, **ML** e **ChatGPT** su Threads. Tutti i file `data.csv` sono presenti nella cartella `Code/data_extraction/data/raw`.

# %%
import pandas as pd
from pathlib import Path

# %%
base_path = Path('../..') / 'data' / 'raw'
paths = {name: base_path / name / 'data.csv' for name in ['AI','ML','ChatGPT']}
dfs = {name: pd.read_csv(path) for name, path in paths.items()}
for name, df in dfs.items():
    print(name, df.shape)
# Out:
# AI (30, 7)
# ML (30, 6)
# ChatGPT (30, 7)

# %%
for name, df in dfs.items():
    display(df.head())
# Out:
#                     pk       user_pk  \
# 0  3555273435077793954  6.331078e+10
# 1  3505685618218888600  6.345893e+10
# 2  3549657636672820072  6.338794e+10
# 3  3501933029318498859  7.042919e+10
# 4  3485889418840696337  6.307192e+10
#
#                                              caption  like_count    taken_at  \
# 0  My son has a good point.\r\nWhy are we calling...         107  1738041642
# 1  I'm a data scientist with (almost) 4 years of ...        1018  1732130313
# 2  Unto the next ⚜️🚀\r\n\r\nMSc. Artificial Intel...        1474  1737372186
# 3  I’m tryna be Ms. 4 degrees!\r\n\r\nBS In Manag...        1203  1731682970
# 4  I’m not AI, artificial intelligence.\r\nMy rea...        1396  1729770422
#
#              username  thread_user_pk
# 0            mlssfshn    6.331078e+10
# 1    codingmermaid.ai    6.345893e+10
# 2       thisisaltgian    6.338794e+10
# 3  thejasminenichelle    7.042919e+10
# 4       aimadonna.art    6.307192e+10
#                     pk       user_pk  \
# 0  3480849807487620533  6.452525e+10
# 1  3556349970031488258  2.890500e+10
# 2  3141726791273787771  6.344238e+10
# 3  3274175088584314747  4.429283e+10
# 4  3535208276422982056  5.175408e+10
#
#                                              caption  like_count  \
# 0             Machine Learning Algorithms Explained.         385
# 1  Michelle Comi attiva un crowdfunding per rifar...         475
# 2  If you are into Machine Learning and Artificia...         154
# 3  5 piattaforme con corsi gratuiti per acquisire...         288
# 4  tech jobs that will boom in 2025\r\n\r\n- data...         320
#
#               taken_at       username
# 0  2024-10-17 12:54:14    cyborgcodes
# 1  2025-01-29 16:59:35       ermideen
# 2  2023-07-07 15:17:20         svp1n0
# 3  2024-01-06 09:08:27  twentyliving_
# 4  2024-12-31 12:54:48      techtoby_
#                     pk       user_pk  \
# 0  3559612855620946452  6.307307e+10
# 1  3559406671493740915  7.130173e+10
# 2  3559725092713442373  6.368215e+10
# 3  3559266613526033864  6.901291e+10
# 4  3559293826575626279  6.799805e+10
#
#                                              caption  like_count    taken_at  \
# 0      I just realized Harry Potter invented ChatGPT       17102  1738558967
# 1  This is literally all you need to make a milli...        1477  1738534362
# 2  Olvida la academia de idiomas. ChatGPT es tu n...        2868  1738572321
# 3  If You're Not Using ChatGPT for Marketing, You...         629  1738517666
# 4  STOP sleeping on Threads!!\r\n\r\n\r\nTHREADS ...         989  1738520910
#
#              username  user_threads_userpk
# 0      aliencoremuzik         6.307307e+10
# 1   wiseadvicetrading         7.130173e+10
# 2      listentogordon         6.368215e+10
# 3     thedailychatgpt         6.901291e+10
# 4  itstherealmercedez         6.799805e+10

# %%
# Numero di righe, colonne e colonne disponibili
import pandas as pd
summary = pd.DataFrame({name: {'rows': len(df), 'columns': len(df.columns), 'fields': df.columns.tolist()} for name, df in dfs.items()}).T
summary
# Out:
#         rows columns                                             fields
# AI        30       7  [pk, user_pk, caption, like_count, taken_at, u...
# ML        30       6  [pk, user_pk, caption, like_count, taken_at, u...
# ChatGPT   30       7  [pk, user_pk, caption, like_count, taken_at, u...

# %%
# Lunghezza media delle caption e like medi
import numpy as np
stats = []
for name, df in dfs.items():
    caption_len = df['caption'].astype(str).str.len()
    stats.append({'dataset': name, 'mean_caption_len': caption_len.mean(), 'mean_like_count': df['like_count'].mean()})
pd.DataFrame(stats)
# Out:
#    dataset  mean_caption_len  mean_like_count
# 0       AI        162.466667      2260.600000
# 1       ML        221.266667       453.166667
# 2  ChatGPT        139.433333      3945.333333
